# %% [markdown]
# <a href="https://colab.research.google.com/github/jaeguk-ju/ju/blob/master/DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MNIST 데이터를 이용하여 손글씨를 식별하는 DNN 구축하기.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, models
from tensorflow.keras.layers import Flatten, Dense, Dropout, Conv2D, MaxPool2D
from tensorflow.keras.utils import plot_model

print(tf.__version__)
# Out:
# 2.3.0

# %%
#mnist = datasets.mnist
#(train_x, train_y), (test_x, test_y) = mnist.load_data()
fashion_mnist = datasets.fashion_mnist
(train_x, train_y), (test_x, test_y) = fashion_mnist.load_data()
train_x = train_x/255.0
test_x = test_x/255.0

print(train_x.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
for col1 in range(9):
  plt.subplot(3,3,col1+1)
  plt.imshow(train_x[col1], cmap=plt.cm.binary)
  plt.xticks([])
  plt.yticks([])
plt.show()

# %%
model = models.Sequential([
  Flatten(input_shape=(28,28)),
  Dense(300, activation='relu'),
  Dense(300, activation='relu'),
  Dense(10, activation='softmax')]
)
model.summary()

plot_model(model, to_file='model_mnist.png', show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                3010
# =================================================================
# Total params: 328,810
# Trainable params: 328,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

hist=model.fit(train_x, train_y, epochs=20, batch_size=100, validation_split=0.10)
# Out:
# Epoch 1/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1459 - accuracy: 0.9442 - val_loss: 0.3497 - val_accuracy: 0.8948
# Epoch 2/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1387 - accuracy: 0.9464 - val_loss: 0.3762 - val_accuracy: 0.8947
# Epoch 3/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1324 - accuracy: 0.9484 - val_loss: 0.3795 - val_accuracy: 0.8938
# Epoch 4/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1289 - accuracy: 0.9508 - val_loss: 0.3577 - val_accuracy: 0.8938
# Epoch 5/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1230 - accuracy: 0.9525 - val_loss: 0.4351 - val_accuracy: 0.8945
# Epoch 6/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1224 - accuracy: 0.9527 - val_loss: 0.3985 - val_accuracy: 0.8968
# Epoch 7/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1140 - accuracy: 0.9564 - val_loss: 0.4030 - val_accuracy: 0.8975
# Epoch 8/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1066 - accuracy: 0.9592 - val_loss: 0.3981 - val_accuracy: 0.8965
# Epoch 9/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1068 - accuracy: 0.9590 - val_loss: 0.4317 - val_accuracy: 0.8958
# Epoch 10/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1028 - accuracy: 0.9608 - val_loss: 0.4008 - val_accuracy: 0.8955
# Epoch 11/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1014 - accuracy: 0.9597 - val_loss: 0.4500 - val_accuracy: 0.8898
# Epoch 12/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0959 - accuracy: 0.9630 - val_loss: 0.4641 - val_accuracy: 0.8832
# Epoch 13/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0925 - accuracy: 0.9639 - val_loss: 0.4492 - val_accuracy: 0.8893
# Epoch 14/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0930 - accuracy: 0.9643 - val_loss: 0.4610 - val_accuracy: 0.8967
# Epoch 15/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0875 - accuracy: 0.9670 - val_loss: 0.4791 - val_accuracy: 0.8850
# Epoch 16/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0848 - accuracy: 0.9675 - val_loss: 0.4558 - val_accuracy: 0.8940
# Epoch 17/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0819 - accuracy: 0.9684 - val_loss: 0.4942 - val_accuracy: 0.8907
# Epoch 18/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0791 - accuracy: 0.9696 - val_loss: 0.4788 - val_accuracy: 0.8923
# Epoch 19/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0796 - accuracy: 0.9693 - val_loss: 0.5364 - val_accuracy: 0.8910
# Epoch 20/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.0698 - accuracy: 0.9737 - val_loss: 0.4759 - val_accuracy: 0.8925

# %%
plt.plot(hist.history['accuracy'], 'b--', label='train')
plt.plot(hist.history['val_accuracy'], 'r-', label='valid')
plt.ylim([0.50,1.01])
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(loc='lower left', fontsize=12)
plt.title('Accuracy trace plot', fontsize=15)
plt.show()

sc = model.evaluate(test_x, test_y)
print('...accuracy: %.3f, loss: %.3f'%(sc[1], sc[0]))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5172 - accuracy: 0.8878
# ...accuracy: 0.888, loss: 0.517

# %%
sc
# Out:
# [0.11050285398960114, 0.982699990272522]

# %%
sc.history
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-afb11fda09e3> in <module>()
# ----> 1 sc.history
#
# AttributeError: 'list' object has no attribute 'history'

# %%
sc
# Out:
# [0.11050285398960114, 0.982699990272522]
