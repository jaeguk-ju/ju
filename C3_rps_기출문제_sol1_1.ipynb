# %% [markdown]
# <a href="https://colab.research.google.com/github/jaeguk-ju/ju/blob/master/C3_rps_%EA%B8%B0%EC%B6%9C%EB%AC%B8%EC%A0%9C_sol1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Computer Vision with CNNs
#
# For this task you will build a classifier for Rock-Paper-Scissors 
# based on the rps dataset.
#
# IMPORTANT: Your final layer should be as shown, do not change the
# provided code, or the tests may fail
#
# IMPORTANT: Images will be tested as 150x150 with 3 bytes of color depth
# So ensure that your input layer is designed accordingly, or the tests
# may fail. 
#
# NOTE THAT THIS IS UNLABELLED DATA. 
# You can use the ImageDataGenerator to automatically label it
# and we have provided some starter code.


# 데이터를 다운로드 받기 
import urllib.request
import zipfile
import tensorflow as tf

url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
urllib.request.urlretrieve(url, 'rps.zip')
local_zip = 'rps.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./tmp/')
zip_ref.close()

###  train 데이터셋을 8:2로  train:valid로 나누기 
import os 
import glob 
import random 
import shutil 
import numpy as np 
ROOT_DIR = './tmp/'
TRAINING_DIR = "./tmp/rps/"


#폴더 없으면 만드는 함수 
def createfolder(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

#상위폴더 만들기 
createfolder(ROOT_DIR+'rps_train0')
createfolder(ROOT_DIR+'rps_valid0')

folders = ['paper', 'rock', 'scissors']

#하위폴더만들기 
for f in folders: 
    createfolder(ROOT_DIR+'rps_train0/'+f)
    createfolder(ROOT_DIR+'rps_valid0/'+f)

# 각 폴더에 파일 카피 (랜덤하게 뽑은 인덱스를 이용)
def copy_files(folder):
    files = glob.glob(TRAINING_DIR + folder + '/*.*')
    ratio = 0.2 
    rand_index = np.random.choice(len(files), int(len(files)*ratio), replace=False)

    for i, f in enumerate(files):
        fname = os.path.basename(f)
        if i in rand_index:
            print('{} is copying to train folder'.format(fname))
            shutil.copy2(os.path.join(TRAINING_DIR, folder, fname), os.path.join(ROOT_DIR, 'rps_valid0', folder))
        else:
            print('{} is copying to valid folder'.format(fname))
            shutil.copy2(os.path.join(TRAINING_DIR, folder, fname),  os.path.join(ROOT_DIR,'rps_train0', folder))

# 각 폴더마다 순회하며 카피 
for a in folders: 
    copy_files(a)
# Out:
# paper02-055.png is copying to train folder
# paper02-044.png is copying to train folder
# paper02-000.png is copying to valid folder
# paper04-094.png is copying to valid folder
# paper02-115.png is copying to valid folder
# paper06-031.png is copying to valid folder
# paper03-002.png is copying to valid folder
# paper06-097.png is copying to valid folder
# paper03-077.png is copying to valid folder
# paper03-009.png is copying to valid folder
# paper01-094.png is copying to valid folder
# paper07-022.png is copying to train folder
# paper03-107.png is copying to valid folder
# paper07-006.png is copying to valid folder
# paper04-020.png is copying to valid folder
# paper05-006.png is copying to valid folder
# paper07-009.png is copying to valid folder
# paper01-080.png is copying to valid folder
# paper02-071.png is copying to valid folder
# paper07-015.png is copying to valid folder
# paper01-093.png is copying to train folder
# paper03-116.png is copying to valid folder
# paper01-025.png is copying to valid folder
# paper02-036.png is copying to valid folder
# paper06-052.png is copying to valid folder
# paper01-010.png is copying to valid folder
# paper06-071.png is copying to valid folder
# paper01-061.png is copying to valid folder
# paper01-119.png is copying to valid folder
# paper07-069.png is copying to valid folder
# paper05-020.png is copying to train folder
# paper05-042.png is copying to train folder
# paper05-016.png is copying to train folder
# paper06-065.png is copying to train folder
# paper04-038.png is copying to train folder
# paper02-033.png is copying to valid folder
# paper06-080.png is copying to valid folder
# paper04-110.png is copying to valid folder
# paper02-009.png is copying to valid folder
# paper01-036.png is copying to train folder
# paper07-010.png is copying to valid folder
# paper03-054.png is copying to valid folder
# paper04-097.png is copying to valid folder
# paper01-030.png is copying to valid folder
# paper01-011.png is copying to valid folder
# paper01-049.png is copying to train folder
# paper06-009.png is copying to valid folder
# paper04-039.png is copying to valid folder
# paper07-004.png is copying to valid folder
# paper02-085.png is copying to valid folder
# paper01-098.png is copying to train folder
# paper01-018.png is copying to valid folder
# paper06-105.png is copying to valid folder
# paper06-078.png is copying to valid folder
# paper05-066.png is copying to valid folder
# paper07-102.png is copying to valid folder
# paper02-042.png is copying to valid folder
# paper02-116.png is copying to train folder
# paper03-114.png is copying to valid folder
# paper05-048.png is copying to valid folder
# paper05-061.png is copying to train folder
# paper01-026.png is copying to valid folder
# paper05-057.png is copying to valid folder
# paper04-114.png is copying to valid folder
# paper07-019.png is copying to valid folder
# paper06-079.png is copying to train folder
# paper04-032.png is copying to valid folder
# paper07-097.png is copying to valid folder
# paper07-073.png is copying to valid folder
# paper02-023.png is copying to valid folder
# paper06-102.png is copying to valid folder
# paper03-093.png is copying to train folder
# paper02-087.png is copying to valid folder
# paper01-099.png is copying to valid folder
# paper03-080.png is copying to valid folder
# paper05-001.png is copying to valid folder
# paper07-060.png is copying to valid folder
# paper05-008.png is copying to train folder
# paper02-019.png is copying to valid folder
# paper07-013.png is copying to valid folder
# paper05-032.png is copying to valid folder
# paper05-002.png is copying to train folder
# paper04-070.png is copying to train folder
# paper03-004.png is copying to valid folder
# paper07-080.png is copying to valid folder
# paper01-069.png is copying to valid folder
# paper04-071.png is copying to train folder
# paper04-105.png is copying to valid folder
# paper06-053.png is copying to train folder
# paper06-027.png is copying to train folder
# paper07-044.png is copying to valid folder
# paper03-081.png is copying to valid folder
# paper04-037.png is copying to train folder
# paper06-093.png is copying to valid folder
# paper04-019.png is copying to valid folder
# paper03-041.png is copying to valid folder
# paper06-091.png is copying to valid folder
# paper02-031.png is copying to train folder
# paper02-021.png is copying to valid folder
# paper07-038.png is copying to valid folder
# paper02-094.png is copying to valid folder
# paper06-046.png is copying to valid folder
# paper03-083.png is copying to train folder
# paper07-095.png is copying to valid folder
# paper01-082.png is copying to valid folder
# paper01-100.png is copying to valid folder
# paper05-090.png is copying to valid folder
# paper07-056.png is copying to valid folder
# paper04-033.png is copying to valid folder
# paper04-112.png is copying to valid folder
# paper07-082.png is copying to valid folder
# paper07-023.png is copying to train folder
# paper03-102.png is copying to valid folder
# paper02-090.png is copying to train folder
# paper02-013.png is copying to valid folder
# paper04-026.png is copying to valid folder
# paper03-074.png is copying to valid folder
# paper01-111.png is copying to train folder
# paper06-073.png is copying to train folder
# paper03-038.png is copying to valid folder
# paper05-005.png is copying to valid folder
# paper06-019.png is copying to valid folder
# paper07-067.png is copying to valid folder
# paper01-060.png is copying to valid folder
# paper02-102.png is copying to valid folder
# paper04-077.png is copying to valid folder
# paper06-005.png is copying to valid folder
# paper03-085.png is copying to valid folder
# paper05-064.png is copying to train folder
# paper03-100.png is copying to train folder
# paper06-119.png is copying to valid folder
# paper03-078.png is copying to valid folder
# paper04-009.png is copying to train folder
# paper06-063.png is copying to valid folder
# paper06-017.png is copying to valid folder
# paper01-081.png is copying to valid folder
# paper03-066.png is copying to valid folder
# paper07-105.png is copying to valid folder
# paper06-113.png is copying to valid folder
# paper02-108.png is copying to valid folder
# paper04-076.png is copying to valid folder
# paper06-029.png is copying to valid folder
# paper07-075.png is copying to valid folder
# paper04-108.png is copying to train folder
# paper06-111.png is copying to valid folder
# paper07-043.png is copying to valid folder
# paper04-011.png is copying to train folder
# paper03-019.png is copying to train folder
# paper05-043.png is copying to train folder
# paper05-062.png is copying to valid folder
# paper04-062.png is copying to train folder
# paper07-005.png is copying to valid folder
# paper02-002.png is copying to valid folder
# paper04-096.png is copying to valid folder
# paper04-040.png is copying to valid folder
# paper04-049.png is copying to valid folder
# paper01-037.png is copying to valid folder
# paper05-086.png is copying to valid folder
# paper03-068.png is copying to valid folder
# paper01-077.png is copying to valid folder
# paper02-075.png is copying to valid folder
# paper05-082.png is copying to train folder
# paper03-091.png is copying to train folder
# paper06-081.png is copying to valid folder
# paper02-022.png is copying to valid folder
# paper04-066.png is copying to valid folder
# paper05-038.png is copying to valid folder
# paper06-023.png is copying to valid folder
# paper05-113.png is copying to valid folder
# paper01-028.png is copying to valid folder
# paper01-044.png is copying to valid folder
# paper03-061.png is copying to valid folder
# paper02-034.png is copying to valid folder
# paper04-004.png is copying to valid folder
# paper07-079.png is copying to valid folder
# paper03-006.png is copying to train folder
# paper02-103.png is copying to valid folder
# paper07-000.png is copying to valid folder
# paper04-099.png is copying to valid folder
# paper05-097.png is copying to valid folder
# paper05-103.png is copying to valid folder
# paper07-058.png is copying to valid folder
# paper01-034.png is copying to valid folder
# paper03-095.png is copying to valid folder
# paper01-023.png is copying to valid folder
# paper04-005.png is copying to valid folder
# paper05-087.png is copying to valid folder
# paper04-098.png is copying to valid folder
# paper02-068.png is copying to valid folder
# paper07-031.png is copying to train folder
# paper07-101.png is copying to valid folder
# paper05-013.png is copying to valid folder
# paper06-085.png is copying to valid folder
# paper02-010.png is copying to valid folder
# paper03-045.png is copying to valid folder
# paper05-055.png is copying to valid folder
# paper06-086.png is copying to valid folder
# paper04-090.png is copying to train folder
# paper06-045.png is copying to valid folder
# paper01-020.png is copying to train folder
# paper04-063.png is copying to valid folder
# paper04-021.png is copying to valid folder
# paper07-018.png is copying to train folder
# paper01-005.png is copying to valid folder
# paper07-077.png is copying to valid folder
# paper05-116.png is copying to valid folder
# paper04-107.png is copying to valid folder
# paper01-115.png is copying to train folder
# paper06-090.png is copying to valid folder
# paper05-065.png is copying to valid folder
# paper03-023.png is copying to valid folder
# paper07-065.png is copying to valid folder
# paper03-029.png is copying to valid folder
# paper06-050.png is copying to train folder
# paper02-012.png is copying to valid folder
# paper05-004.png is copying to train folder
# paper07-076.png is copying to valid folder
# paper04-075.png is copying to valid folder
# paper01-019.png is copying to valid folder
# paper05-056.png is copying to valid folder
# paper05-015.png is copying to train folder
# paper03-003.png is copying to train folder
# paper03-103.png is copying to train folder
# paper01-086.png is copying to valid folder
# paper01-071.png is copying to valid folder
# paper01-085.png is copying to train folder
# paper06-077.png is copying to valid folder
# paper05-089.png is copying to train folder
# paper07-059.png is copying to valid folder
# paper06-041.png is copying to train folder
# paper04-003.png is copying to valid folder
# paper04-067.png is copying to train folder
# paper07-106.png is copying to valid folder
# paper05-075.png is copying to valid folder
# paper03-051.png is copying to valid folder
# paper05-028.png is copying to valid folder
# paper04-052.png is copying to valid folder
# paper04-104.png is copying to valid folder
# paper02-100.png is copying to valid folder
# paper06-010.png is copying to valid folder
# paper04-059.png is copying to valid folder
# paper01-076.png is copying to valid folder
# paper04-048.png is copying to valid folder
# paper06-042.png is copying to valid folder
# paper01-067.png is copying to valid folder
# paper02-104.png is copying to valid folder
# paper06-054.png is copying to train folder
# paper02-079.png is copying to valid folder
# paper05-077.png is copying to valid folder
# paper01-017.png is copying to valid folder
# paper03-030.png is copying to valid folder
# paper05-111.png is copying to valid folder
# paper04-043.png is copying to valid folder
# paper02-067.png is copying to valid folder
# paper05-085.png is copying to valid folder
# paper01-042.png is copying to train folder
# paper06-083.png is copying to valid folder
# paper04-072.png is copying to valid folder
# paper05-079.png is copying to valid folder
# paper06-072.png is copying to valid folder
# paper02-016.png is copying to train folder
# paper02-048.png is copying to valid folder
# paper06-098.png is copying to train folder
# paper05-063.png is copying to train folder
# paper02-059.png is copying to valid folder
# paper06-116.png is copying to valid folder
# paper02-047.png is copying to train folder
# paper01-101.png is copying to valid folder
# paper03-073.png is copying to valid folder
# paper03-065.png is copying to valid folder
# paper01-064.png is copying to valid folder
# paper07-087.png is copying to valid folder
# paper06-012.png is copying to train folder
# paper02-056.png is copying to valid folder
# paper07-088.png is copying to valid folder
# paper01-065.png is copying to valid folder
# paper06-034.png is copying to valid folder
# paper03-007.png is copying to train folder
# paper06-007.png is copying to valid folder
# paper01-058.png is copying to valid folder
# paper06-030.png is copying to valid folder
# paper04-079.png is copying to train folder
# paper06-049.png is copying to valid folder
# paper05-018.png is copying to valid folder
# paper02-025.png is copying to valid folder
# paper03-087.png is copying to valid folder
# paper01-110.png is copying to valid folder
# paper03-086.png is copying to valid folder
# paper03-108.png is copying to train folder
# paper04-054.png is copying to train folder
# paper02-097.png is copying to valid folder
# paper02-080.png is copying to valid folder
# paper01-006.png is copying to valid folder
# paper01-022.png is copying to train folder
# paper07-108.png is copying to valid folder
# paper04-051.png is copying to valid folder
# paper01-021.png is copying to valid folder
# paper02-014.png is copying to valid folder
# paper03-098.png is copying to train folder
# paper07-011.png is copying to valid folder
# paper05-070.png is copying to train folder
# paper02-060.png is copying to valid folder
# paper02-046.png is copying to train folder
# paper04-027.png is copying to valid folder
# paper03-082.png is copying to valid folder
# paper05-011.png is copying to valid folder
# paper06-096.png is copying to train folder
# paper04-053.png is copying to valid folder
# paper02-045.png is copying to valid folder
# paper04-024.png is copying to valid folder
# paper06-040.png is copying to valid folder
# paper03-021.png is copying to valid folder
# paper04-028.png is copying to train folder
# paper04-081.png is copying to valid folder
# paper04-035.png is copying to valid folder
# paper05-023.png is copying to valid folder
# paper01-029.png is copying to valid folder
# paper06-118.png is copying to valid folder
# paper03-106.png is copying to valid folder
# paper02-105.png is copying to train folder
# paper02-051.png is copying to valid folder
# paper01-083.png is copying to valid folder
# paper06-115.png is copying to train folder
# paper07-054.png is copying to valid folder
# paper06-021.png is copying to valid folder
# paper02-035.png is copying to valid folder
# paper03-088.png is copying to valid folder
# paper01-055.png is copying to valid folder
# paper03-090.png is copying to valid folder
# paper01-087.png is copying to valid folder
# paper04-058.png is copying to valid folder
# paper04-055.png is copying to valid folder
# paper07-119.png is copying to train folder
# paper06-011.png is copying to valid folder
# paper07-068.png is copying to train folder
# paper03-111.png is copying to train folder
# paper02-011.png is copying to valid folder
# paper02-096.png is copying to valid folder
# paper03-057.png is copying to valid folder
# paper03-050.png is copying to valid folder
# paper01-052.png is copying to valid folder
# paper02-054.png is copying to valid folder
# paper02-004.png is copying to train folder
# paper05-118.png is copying to valid folder
# paper06-024.png is copying to train folder
# paper01-031.png is copying to train folder
# paper01-062.png is copying to valid folder
# paper01-096.png is copying to valid folder
# paper03-043.png is copying to valid folder
# paper03-011.png is copying to valid folder
# paper01-002.png is copying to valid folder
# paper04-008.png is copying to valid folder
# paper06-035.png is copying to valid folder
# paper03-022.png is copying to train folder
# paper05-034.png is copying to valid folder
# paper04-010.png is copying to train folder
# paper02-003.png is copying to valid folder
# paper06-048.png is copying to valid folder
# paper05-022.png is copying to valid folder
# paper01-114.png is copying to valid folder
# paper06-109.png is copying to valid folder
# paper07-064.png is copying to valid folder
# paper01-050.png is copying to train folder
# paper02-095.png is copying to valid folder
# paper02-099.png is copying to valid folder
# paper07-072.png is copying to train folder
# paper02-018.png is copying to train folder
# paper01-074.png is copying to valid folder
# paper01-117.png is copying to valid folder
# paper01-079.png is copying to valid folder
# paper07-027.png is copying to valid folder
# paper03-097.png is copying to valid folder
# paper03-046.png is copying to valid folder
# paper04-101.png is copying to valid folder
# paper07-114.png is copying to train folder
# paper05-069.png is copying to valid folder
# paper07-040.png is copying to valid folder
# paper02-083.png is copying to valid folder
# paper06-025.png is copying to valid folder
# paper07-020.png is copying to valid folder
# paper05-073.png is copying to valid folder
# paper06-022.png is copying to valid folder
# paper05-033.png is copying to valid folder
# paper06-089.png is copying to train folder
# paper01-059.png is copying to valid folder
# paper01-109.png is copying to train folder
# paper07-014.png is copying to valid folder
# paper02-076.png is copying to valid folder
# paper01-024.png is copying to valid folder
# paper07-035.png is copying to valid folder
# paper01-027.png is copying to valid folder
# paper04-029.png is copying to valid folder
# paper01-041.png is copying to valid folder
# paper07-062.png is copying to train folder
# paper02-037.png is copying to valid folder
# paper04-025.png is copying to valid folder
# paper01-105.png is copying to valid folder
# paper07-070.png is copying to valid folder
# paper06-106.png is copying to valid folder
# paper07-030.png is copying to valid folder
# paper04-065.png is copying to valid folder
# paper04-109.png is copying to train folder
# paper06-008.png is copying to valid folder
# paper01-003.png is copying to valid folder
# paper05-050.png is copying to valid folder
# paper03-075.png is copying to valid folder
# paper05-080.png is copying to valid folder
# paper06-028.png is copying to valid folder
# paper04-113.png is copying to valid folder
# paper07-096.png is copying to train folder
# paper06-047.png is copying to train folder
# paper05-019.png is copying to valid folder
# paper07-007.png is copying to valid folder
# paper01-048.png is copying to valid folder
# paper05-058.png is copying to valid folder
# paper06-076.png is copying to valid folder
# paper05-076.png is copying to valid folder
# paper06-015.png is copying to valid folder
# paper05-110.png is copying to valid folder
# paper04-085.png is copying to valid folder
# paper06-108.png is copying to valid folder
# paper07-090.png is copying to valid folder
# paper06-075.png is copying to valid folder
# paper02-008.png is copying to valid folder
# paper03-014.png is copying to valid folder
# paper07-037.png is copying to valid folder
# paper04-061.png is copying to valid folder
# paper03-035.png is copying to train folder
# paper02-032.png is copying to train folder
# paper02-088.png is copying to valid folder
# paper01-013.png is copying to train folder
# paper05-030.png is copying to valid folder
# paper04-068.png is copying to valid folder
# paper06-069.png is copying to train folder
# paper05-031.png is copying to train folder
# paper06-037.png is copying to valid folder
# paper05-099.png is copying to valid folder
# paper07-107.png is copying to valid folder
# paper03-079.png is copying to valid folder
# paper04-013.png is copying to train folder
# paper06-103.png is copying to valid folder
# paper01-078.png is copying to valid folder
# paper01-007.png is copying to train folder
# paper03-005.png is copying to valid folder
# paper07-048.png is copying to train folder
# paper07-081.png is copying to valid folder
# paper07-008.png is copying to train folder
# paper04-023.png is copying to valid folder
# paper04-050.png is copying to valid folder
# paper04-069.png is copying to train folder
# paper02-098.png is copying to valid folder
# paper07-063.png is copying to valid folder
# paper06-003.png is copying to valid folder
# paper03-105.png is copying to train folder
# paper03-053.png is copying to valid folder
# paper02-114.png is copying to valid folder
# paper03-048.png is copying to valid folder
# paper04-031.png is copying to valid folder
# paper01-047.png is copying to valid folder
# paper04-047.png is copying to valid folder
# paper01-012.png is copying to valid folder
# paper02-089.png is copying to valid folder
# paper06-112.png is copying to valid folder
# paper04-111.png is copying to train folder
# paper01-108.png is copying to train folder
# paper02-065.png is copying to valid folder
# paper02-117.png is copying to valid folder
# paper03-069.png is copying to train folder
# paper03-012.png is copying to valid folder
# paper03-089.png is copying to valid folder
# paper07-045.png is copying to valid folder
# paper07-066.png is copying to valid folder
# paper04-042.png is copying to valid folder
# paper06-001.png is copying to valid folder
# paper07-094.png is copying to valid folder
# paper01-051.png is copying to valid folder
# paper05-003.png is copying to train folder
# paper07-074.png is copying to valid folder
# paper03-110.png is copying to valid folder
# paper01-053.png is copying to valid folder
# paper05-088.png is copying to valid folder
# paper02-073.png is copying to valid folder
# paper03-044.png is copying to valid folder
# paper04-102.png is copying to valid folder
# paper04-045.png is copying to valid folder
# paper05-027.png is copying to valid folder
# paper01-033.png is copying to valid folder
# paper03-117.png is copying to valid folder
# paper03-000.png is copying to train folder
# paper07-033.png is copying to valid folder
# paper01-000.png is copying to train folder
# paper03-094.png is copying to valid folder
# paper06-056.png is copying to valid folder
# paper07-025.png is copying to valid folder
# paper02-015.png is copying to valid folder
# paper01-014.png is copying to valid folder
# paper02-017.png is copying to valid folder
# paper04-056.png is copying to train folder
# paper07-055.png is copying to valid folder
# paper03-031.png is copying to valid folder
# paper05-054.png is copying to valid folder
# paper05-112.png is copying to valid folder
# paper05-036.png is copying to valid folder
# paper07-036.png is copying to valid folder
# paper03-027.png is copying to valid folder
# paper01-016.png is copying to valid folder
# paper06-057.png is copying to valid folder
# paper07-001.png is copying to valid folder
# paper01-084.png is copying to valid folder
# paper05-021.png is copying to valid folder
# paper01-039.png is copying to valid folder
# paper05-119.png is copying to train folder
# paper01-104.png is copying to valid folder
# paper07-012.png is copying to valid folder
# paper03-047.png is copying to valid folder
# paper05-037.png is copying to valid folder
# paper02-081.png is copying to valid folder
# paper02-040.png is copying to valid folder
# paper02-052.png is copying to valid folder
# paper05-098.png is copying to valid folder
# paper06-088.png is copying to valid folder
# paper07-034.png is copying to valid folder
# paper04-006.png is copying to valid folder
# paper07-002.png is copying to valid folder
# paper06-092.png is copying to train folder
# paper01-057.png is copying to valid folder
# paper02-063.png is copying to valid folder
# paper02-020.png is copying to valid folder
# paper05-000.png is copying to train folder
# paper06-068.png is copying to train folder
# paper02-110.png is copying to valid folder
# paper01-097.png is copying to valid folder
# paper06-064.png is copying to valid folder
# paper03-099.png is copying to valid folder
# paper05-010.png is copying to valid folder
# paper06-095.png is copying to valid folder
# paper04-093.png is copying to valid folder
# paper05-095.png is copying to valid folder
# paper06-039.png is copying to valid folder
# paper04-018.png is copying to valid folder
# paper03-070.png is copying to valid folder
# paper01-092.png is copying to valid folder
# paper05-072.png is copying to valid folder
# paper05-045.png is copying to valid folder
# paper07-110.png is copying to valid folder
# paper05-071.png is copying to valid folder
# paper03-115.png is copying to valid folder
# paper07-071.png is copying to train folder
# paper03-026.png is copying to valid folder
# paper01-054.png is copying to valid folder
# paper02-066.png is copying to valid folder
# paper02-041.png is copying to valid folder
# paper02-007.png is copying to valid folder
# paper06-016.png is copying to valid folder
# paper05-084.png is copying to valid folder
# paper02-058.png is copying to valid folder
# paper05-093.png is copying to train folder
# paper04-088.png is copying to train folder
# paper04-106.png is copying to valid folder
# paper04-115.png is copying to valid folder
# paper01-088.png is copying to valid folder
# paper06-099.png is copying to valid folder
# paper07-103.png is copying to valid folder
# paper01-116.png is copying to valid folder
# paper04-092.png is copying to train folder
# paper02-028.png is copying to train folder
# paper02-101.png is copying to valid folder
# paper06-084.png is copying to valid folder
# paper03-033.png is copying to valid folder
# paper02-093.png is copying to valid folder
# paper06-044.png is copying to valid folder
# paper05-049.png is copying to valid folder
# paper06-033.png is copying to train folder
# paper02-005.png is copying to train folder
# paper03-076.png is copying to valid folder
# paper05-074.png is copying to valid folder
# paper04-073.png is copying to valid folder
# paper01-004.png is copying to train folder
# paper04-015.png is copying to valid folder
# paper01-035.png is copying to valid folder
# paper07-053.png is copying to valid folder
# paper07-049.png is copying to valid folder
# paper05-026.png is copying to valid folder
# paper07-057.png is copying to train folder
# paper05-096.png is copying to valid folder
# paper03-058.png is copying to valid folder
# paper03-040.png is copying to valid folder
# paper06-070.png is copying to valid folder
# paper04-080.png is copying to valid folder
# paper07-118.png is copying to valid folder
# paper07-104.png is copying to train folder
# paper01-118.png is copying to valid folder
# paper06-006.png is copying to valid folder
# paper05-081.png is copying to valid folder
# paper06-110.png is copying to valid folder
# paper02-062.png is copying to valid folder
# paper04-103.png is copying to train folder
# paper06-061.png is copying to valid folder
# paper02-053.png is copying to valid folder
# paper07-115.png is copying to valid folder
# paper07-041.png is copying to valid folder
# paper04-007.png is copying to valid folder
# paper04-116.png is copying to valid folder
# paper03-028.png is copying to valid folder
# paper01-008.png is copying to valid folder
# paper03-008.png is copying to valid folder
# paper04-036.png is copying to valid folder
# paper03-067.png is copying to valid folder
# paper02-111.png is copying to train folder
# paper05-039.png is copying to valid folder
# paper07-003.png is copying to valid folder
# paper04-084.png is copying to train folder
# paper05-083.png is copying to valid folder
# paper02-072.png is copying to valid folder
# paper02-001.png is copying to valid folder
# paper03-060.png is copying to valid folder
# paper02-057.png is copying to valid folder
# paper02-029.png is copying to valid folder
# paper06-100.png is copying to valid folder
# paper04-091.png is copying to valid folder
# paper03-049.png is copying to valid folder
# paper07-113.png is copying to valid folder
# paper03-119.png is copying to valid folder
# paper07-091.png is copying to valid folder
# paper04-002.png is copying to valid folder
# paper02-024.png is copying to valid folder
# paper02-118.png is copying to valid folder
# paper05-012.png is copying to valid folder
# paper06-043.png is copying to valid folder
# paper03-039.png is copying to train folder
# paper02-113.png is copying to valid folder
# paper06-062.png is copying to valid folder
# paper03-018.png is copying to valid folder
# paper03-101.png is copying to valid folder
# paper02-077.png is copying to valid folder
# paper04-017.png is copying to valid folder
# paper05-109.png is copying to valid folder
# paper07-117.png is copying to valid folder
# paper04-083.png is copying to valid folder
# paper03-001.png is copying to train folder
# paper05-108.png is copying to valid folder
# paper07-029.png is copying to valid folder
# paper02-106.png is copying to valid folder
# paper02-064.png is copying to train folder
# paper07-083.png is copying to valid folder
# paper06-094.png is copying to valid folder
# paper05-051.png is copying to valid folder
# paper06-000.png is copying to valid folder
# paper02-006.png is copying to valid folder
# paper01-070.png is copying to valid folder
# paper05-114.png is copying to valid folder
# paper06-082.png is copying to valid folder
# paper01-106.png is copying to train folder
# paper03-010.png is copying to valid folder
# paper05-007.png is copying to valid folder
# paper04-087.png is copying to train folder
# paper04-041.png is copying to valid folder
# paper04-117.png is copying to valid folder
# paper07-092.png is copying to valid folder
# paper03-059.png is copying to valid folder
# paper07-085.png is copying to valid folder
# paper05-025.png is copying to valid folder
# paper02-112.png is copying to valid folder
# paper03-032.png is copying to valid folder
# paper03-072.png is copying to valid folder
# paper02-038.png is copying to train folder
# paper06-026.png is copying to valid folder
# paper05-107.png is copying to train folder
# paper01-032.png is copying to valid folder
# paper03-064.png is copying to valid folder
# paper07-016.png is copying to valid folder
# paper05-040.png is copying to valid folder
# paper06-002.png is copying to train folder
# paper02-074.png is copying to train folder
# paper01-090.png is copying to valid folder
# paper01-066.png is copying to valid folder
# paper07-024.png is copying to valid folder
# paper07-089.png is copying to valid folder
# paper06-058.png is copying to train folder
# paper01-063.png is copying to train folder
# paper05-046.png is copying to valid folder
# paper04-022.png is copying to valid folder
# paper03-013.png is copying to valid folder
# paper07-046.png is copying to valid folder
# paper02-027.png is copying to valid folder
# paper01-073.png is copying to valid folder
# paper03-056.png is copying to valid folder
# paper06-087.png is copying to valid folder
# paper03-118.png is copying to valid folder
# paper01-015.png is copying to valid folder
# paper02-107.png is copying to valid folder
# paper04-060.png is copying to valid folder
# paper02-078.png is copying to valid folder
# paper06-013.png is copying to valid folder
# paper06-014.png is copying to train folder
# paper04-057.png is copying to train folder
# paper06-107.png is copying to valid folder
# paper01-107.png is copying to valid folder
# paper02-082.png is copying to valid folder
# paper05-101.png is copying to valid folder
# paper07-026.png is copying to valid folder
# paper07-061.png is copying to valid folder
# paper01-045.png is copying to train folder
# paper07-109.png is copying to valid folder
# paper02-030.png is copying to valid folder
# paper05-047.png is copying to valid folder
# paper07-093.png is copying to valid folder
# paper01-089.png is copying to valid folder
# paper05-041.png is copying to train folder
# paper05-052.png is copying to train folder
# paper06-060.png is copying to valid folder
# paper04-064.png is copying to train folder
# paper07-098.png is copying to valid folder
# paper07-017.png is copying to train folder
# paper01-113.png is copying to valid folder
# paper02-091.png is copying to train folder
# paper03-052.png is copying to valid folder
# paper01-095.png is copying to valid folder
# paper07-052.png is copying to valid folder
# paper03-112.png is copying to valid folder
# paper02-039.png is copying to train folder
# paper06-059.png is copying to valid folder
# paper07-042.png is copying to train folder
# paper03-084.png is copying to valid folder
# paper05-044.png is copying to valid folder
# paper06-067.png is copying to valid folder
# paper03-024.png is copying to valid folder
# paper01-091.png is copying to valid folder
# paper07-021.png is copying to valid folder
# paper03-055.png is copying to valid folder
# paper02-050.png is copying to valid folder
# paper05-105.png is copying to train folder
# paper05-078.png is copying to valid folder
# paper06-114.png is copying to valid folder
# paper03-109.png is copying to valid folder
# paper01-072.png is copying to valid folder
# paper03-092.png is copying to valid folder
# paper04-012.png is copying to valid folder
# paper01-112.png is copying to valid folder
# paper03-036.png is copying to train folder
# paper03-104.png is copying to valid folder
# paper04-016.png is copying to valid folder
# paper03-015.png is copying to valid folder
# paper03-016.png is copying to train folder
# paper07-111.png is copying to valid folder
# paper06-104.png is copying to valid folder
# paper07-099.png is copying to valid folder
# paper04-119.png is copying to valid folder
# paper02-070.png is copying to valid folder
# paper07-100.png is copying to valid folder
# paper05-059.png is copying to valid folder
# paper05-106.png is copying to valid folder
# paper04-044.png is copying to valid folder
# paper05-060.png is copying to valid folder
# paper02-049.png is copying to train folder
# paper05-053.png is copying to valid folder
# paper01-102.png is copying to valid folder
# paper06-036.png is copying to valid folder
# paper07-084.png is copying to valid folder
# paper02-069.png is copying to valid folder
# paper01-040.png is copying to train folder
# paper05-017.png is copying to valid folder
# paper07-028.png is copying to train folder
# paper05-100.png is copying to valid folder
# paper02-043.png is copying to valid folder
# paper05-115.png is copying to valid folder
# paper06-032.png is copying to valid folder
# paper04-001.png is copying to valid folder
# paper07-078.png is copying to valid folder
# paper06-117.png is copying to valid folder
# paper04-089.png is copying to valid folder
# paper06-004.png is copying to valid folder
# paper03-020.png is copying to valid folder
# paper03-096.png is copying to valid folder
# paper05-035.png is copying to train folder
# paper05-024.png is copying to valid folder
# paper05-068.png is copying to valid folder
# paper06-055.png is copying to valid folder
# paper04-078.png is copying to valid folder
# paper03-042.png is copying to valid folder
# paper04-074.png is copying to valid folder
# paper02-092.png is copying to train folder
# paper05-029.png is copying to valid folder
# paper05-102.png is copying to valid folder
# paper05-014.png is copying to valid folder
# paper07-050.png is copying to train folder
# paper04-014.png is copying to train folder
# paper01-038.png is copying to valid folder
# paper03-017.png is copying to train folder
# paper04-000.png is copying to train folder
# paper01-043.png is copying to valid folder
# paper04-095.png is copying to valid folder
# paper03-037.png is copying to train folder
# paper01-046.png is copying to train folder
# paper01-068.png is copying to valid folder
# paper07-116.png is copying to valid folder
# paper07-112.png is copying to valid folder
# paper05-067.png is copying to valid folder
# paper06-074.png is copying to valid folder
# paper06-020.png is copying to valid folder
# paper04-086.png is copying to valid folder
# paper04-118.png is copying to train folder
# paper05-091.png is copying to valid folder
# paper05-104.png is copying to train folder
# paper06-101.png is copying to train folder
# paper03-071.png is copying to valid folder
# paper03-113.png is copying to train folder
# paper02-109.png is copying to valid folder
# paper01-009.png is copying to valid folder
# paper05-094.png is copying to train folder
# paper05-117.png is copying to valid folder
# paper05-009.png is copying to valid folder
# paper01-075.png is copying to valid folder
# paper06-038.png is copying to valid folder
# paper07-032.png is copying to valid folder
# paper02-086.png is copying to valid folder
# paper02-026.png is copying to valid folder
# paper01-056.png is copying to valid folder
# paper01-001.png is copying to train folder
# paper06-051.png is copying to valid folder
# paper04-046.png is copying to train folder
# paper03-063.png is copying to valid folder
# paper03-034.png is copying to valid folder
# paper02-061.png is copying to valid folder
# paper02-084.png is copying to valid folder
# paper04-030.png is copying to valid folder
# paper01-103.png is copying to valid folder
# paper07-051.png is copying to valid folder
# paper04-034.png is copying to valid folder
# paper02-119.png is copying to valid folder
# paper03-025.png is copying to valid folder
# paper07-047.png is copying to valid folder
# paper06-018.png is copying to valid folder
# paper07-086.png is copying to valid folder
# paper04-082.png is copying to valid folder
# paper07-039.png is copying to valid folder
# paper04-100.png is copying to valid folder
# paper05-092.png is copying to valid folder
# paper06-066.png is copying to valid folder
# paper03-062.png is copying to valid folder
# rock04-032.png is copying to valid folder
# rock02-018.png is copying to valid folder
# rock05ck01-014.png is copying to valid folder
# rock01-095.png is copying to valid folder
# rock03-091.png is copying to valid folder
# rock02-048.png is copying to valid folder
# rock01-067.png is copying to valid folder
# rock06ck02-033.png is copying to train folder
# rock04-044.png is copying to train folder
# rock05ck01-042.png is copying to valid folder
# rock05ck01-099.png is copying to valid folder
# rock05ck01-080.png is copying to valid folder
# rock03-076.png is copying to valid folder
# rock04-037.png is copying to train folder
# rock02-070.png is copying to valid folder
# rock06ck02-067.png is copying to valid folder
# rock01-033.png is copying to train folder
# rock03-062.png is copying to valid folder
# rock06ck02-089.png is copying to valid folder
# rock05ck01-043.png is copying to valid folder
# rock04-101.png is copying to valid folder
# rock01-007.png is copying to train folder
# rock02-063.png is copying to valid folder
# rock07-k03-067.png is copying to valid folder
# rock07-k03-090.png is copying to valid folder
# rock02-084.png is copying to valid folder
# rock05ck01-107.png is copying to valid folder
# rock04-094.png is copying to train folder
# rock06ck02-065.png is copying to valid folder
# rock05ck01-085.png is copying to valid folder
# rock01-097.png is copying to train folder
# rock01-086.png is copying to train folder
# rock01-094.png is copying to valid folder
# rock06ck02-043.png is copying to valid folder
# rock07-k03-085.png is copying to valid folder
# rock04-106.png is copying to train folder
# rock03-104.png is copying to valid folder
# rock06ck02-015.png is copying to valid folder
# rock04-061.png is copying to train folder
# rock02-118.png is copying to valid folder
# rock04-093.png is copying to valid folder
# rock06ck02-088.png is copying to train folder
# rock05ck01-056.png is copying to valid folder
# rock04-020.png is copying to valid folder
# rock01-026.png is copying to valid folder
# rock05ck01-081.png is copying to valid folder
# rock05ck01-041.png is copying to train folder
# rock01-075.png is copying to train folder
# rock07-k03-092.png is copying to valid folder
# rock07-k03-019.png is copying to valid folder
# rock02-006.png is copying to valid folder
# rock07-k03-087.png is copying to valid folder
# rock07-k03-082.png is copying to valid folder
# rock07-k03-113.png is copying to valid folder
# rock07-k03-071.png is copying to valid folder
# rock07-k03-086.png is copying to valid folder
# rock01-027.png is copying to valid folder
# rock02-050.png is copying to valid folder
# rock06ck02-030.png is copying to valid folder
# rock06ck02-056.png is copying to valid folder
# rock01-111.png is copying to valid folder
# rock07-k03-112.png is copying to train folder
# rock01-051.png is copying to valid folder
# rock06ck02-084.png is copying to valid folder
# rock03-036.png is copying to train folder
# rock05ck01-026.png is copying to train folder
# rock01-059.png is copying to train folder
# rock05ck01-003.png is copying to valid folder
# rock04-119.png is copying to valid folder
# rock05ck01-065.png is copying to valid folder
# rock06ck02-074.png is copying to valid folder
# rock02-032.png is copying to valid folder
# rock06ck02-059.png is copying to train folder
# rock03-073.png is copying to valid folder
# rock01-041.png is copying to valid folder
# rock05ck01-016.png is copying to valid folder
# rock06ck02-047.png is copying to valid folder
# rock01-115.png is copying to valid folder
# rock05ck01-023.png is copying to train folder
# rock07-k03-091.png is copying to train folder
# rock05ck01-114.png is copying to train folder
# rock03-054.png is copying to valid folder
# rock06ck02-069.png is copying to valid folder
# rock04-091.png is copying to valid folder
# rock04-118.png is copying to valid folder
# rock06ck02-087.png is copying to valid folder
# rock07-k03-012.png is copying to valid folder
# rock05ck01-066.png is copying to train folder
# rock01-104.png is copying to valid folder
# rock01-037.png is copying to valid folder
# rock07-k03-006.png is copying to valid folder
# rock07-k03-066.png is copying to valid folder
# rock06ck02-073.png is copying to valid folder
# rock01-014.png is copying to valid folder
# rock03-088.png is copying to valid folder
# rock05ck01-036.png is copying to valid folder
# rock03-026.png is copying to valid folder
# rock03-069.png is copying to valid folder
# rock04-028.png is copying to valid folder
# rock03-040.png is copying to valid folder
# rock05ck01-073.png is copying to valid folder
# rock01-049.png is copying to valid folder
# rock01-024.png is copying to valid folder
# rock07-k03-098.png is copying to valid folder
# rock07-k03-101.png is copying to valid folder
# rock03-071.png is copying to valid folder
# rock04-054.png is copying to valid folder
# rock04-024.png is copying to valid folder
# rock01-042.png is copying to valid folder
# rock02-045.png is copying to valid folder
# rock02-009.png is copying to train folder
# rock02-094.png is copying to valid folder
# rock02-023.png is copying to train folder
# rock05ck01-090.png is copying to valid folder
# rock01-062.png is copying to train folder
# rock04-025.png is copying to valid folder
# rock02-077.png is copying to valid folder
# rock06ck02-060.png is copying to valid folder
# rock04-033.png is copying to valid folder
# rock04-089.png is copying to valid folder
# rock03-008.png is copying to valid folder
# rock01-100.png is copying to valid folder
# rock04-079.png is copying to valid folder
# rock02-062.png is copying to valid folder
# rock02-073.png is copying to train folder
# rock07-k03-107.png is copying to valid folder
# rock01-028.png is copying to valid folder
# rock01-085.png is copying to valid folder
# rock05ck01-108.png is copying to valid folder
# rock03-101.png is copying to train folder
# rock02-065.png is copying to valid folder
# rock05ck01-105.png is copying to train folder
# rock02-036.png is copying to valid folder
# rock06ck02-107.png is copying to valid folder
# rock05ck01-021.png is copying to valid folder
# rock02-008.png is copying to valid folder
# rock01-010.png is copying to train folder
# rock02-100.png is copying to train folder
# rock06ck02-034.png is copying to valid folder
# rock07-k03-053.png is copying to valid folder
# rock04-103.png is copying to valid folder
# rock02-014.png is copying to valid folder
# rock04-016.png is copying to valid folder
# rock02-043.png is copying to valid folder
# rock06ck02-096.png is copying to valid folder
# rock01-117.png is copying to valid folder
# rock05ck01-029.png is copying to valid folder
# rock06ck02-086.png is copying to train folder
# rock04-115.png is copying to train folder
# rock02-046.png is copying to valid folder
# rock01-099.png is copying to train folder
# rock07-k03-009.png is copying to valid folder
# rock03-013.png is copying to valid folder
# rock07-k03-024.png is copying to train folder
# rock06ck02-036.png is copying to train folder
# rock01-090.png is copying to train folder
# rock04-046.png is copying to train folder
# rock06ck02-006.png is copying to valid folder
# rock07-k03-096.png is copying to valid folder
# rock06ck02-114.png is copying to valid folder
# rock05ck01-083.png is copying to valid folder
# rock01-047.png is copying to valid folder
# rock05ck01-033.png is copying to valid folder
# rock02-097.png is copying to valid folder
# rock07-k03-061.png is copying to valid folder
# rock02-092.png is copying to valid folder
# rock01-076.png is copying to valid folder
# rock06ck02-014.png is copying to train folder
# rock07-k03-078.png is copying to valid folder
# rock03-022.png is copying to valid folder
# rock03-106.png is copying to train folder
# rock05ck01-064.png is copying to valid folder
# rock05ck01-030.png is copying to valid folder
# rock07-k03-115.png is copying to train folder
# rock06ck02-103.png is copying to valid folder
# rock06ck02-010.png is copying to valid folder
# rock04-070.png is copying to valid folder
# rock03-024.png is copying to valid folder
# rock01-082.png is copying to valid folder
# rock01-063.png is copying to train folder
# rock03-044.png is copying to valid folder
# rock06ck02-091.png is copying to valid folder
# rock07-k03-062.png is copying to train folder
# rock02-024.png is copying to valid folder
# rock03-028.png is copying to valid folder
# rock07-k03-094.png is copying to train folder
# rock04-019.png is copying to valid folder
# rock04-047.png is copying to valid folder
# rock05ck01-038.png is copying to valid folder
# rock04-011.png is copying to valid folder
# rock05ck01-048.png is copying to train folder
# rock07-k03-036.png is copying to train folder
# rock01-101.png is copying to valid folder
# rock05ck01-092.png is copying to valid folder
# rock04-066.png is copying to valid folder
# rock07-k03-116.png is copying to valid folder
# rock02-110.png is copying to valid folder
# rock03-080.png is copying to valid folder
# rock03-107.png is copying to train folder
# rock02-069.png is copying to train folder
# rock03-108.png is copying to valid folder
# rock06ck02-048.png is copying to valid folder
# rock03-002.png is copying to valid folder
# rock05ck01-006.png is copying to valid folder
# rock03-077.png is copying to valid folder
# rock07-k03-002.png is copying to valid folder
# rock04-036.png is copying to valid folder
# rock07-k03-016.png is copying to valid folder
# rock05ck01-118.png is copying to valid folder
# rock02-089.png is copying to valid folder
# rock07-k03-051.png is copying to valid folder
# rock05ck01-011.png is copying to valid folder
# rock02-022.png is copying to valid folder
# rock06ck02-082.png is copying to valid folder
# rock05ck01-045.png is copying to valid folder
# rock03-098.png is copying to valid folder
# rock02-103.png is copying to valid folder
# rock03-043.png is copying to valid folder
# rock06ck02-099.png is copying to valid folder
# rock03-074.png is copying to valid folder
# rock01-050.png is copying to valid folder
# rock07-k03-117.png is copying to valid folder
# rock06ck02-039.png is copying to valid folder
# rock05ck01-101.png is copying to valid folder
# rock03-087.png is copying to train folder
# rock05ck01-049.png is copying to valid folder
# rock06ck02-113.png is copying to train folder
# rock01-017.png is copying to valid folder
# rock06ck02-002.png is copying to valid folder
# rock04-096.png is copying to valid folder
# rock06ck02-027.png is copying to valid folder
# rock02-003.png is copying to valid folder
# rock04-071.png is copying to valid folder
# rock02-002.png is copying to valid folder
# rock03-084.png is copying to valid folder
# rock03-003.png is copying to valid folder
# rock05ck01-044.png is copying to valid folder
# rock07-k03-027.png is copying to valid folder
# rock06ck02-068.png is copying to valid folder
# rock02-053.png is copying to train folder
# rock02-096.png is copying to valid folder
# rock07-k03-088.png is copying to valid folder
# rock04-027.png is copying to valid folder
# rock07-k03-073.png is copying to train folder
# rock01-073.png is copying to valid folder
# rock07-k03-057.png is copying to valid folder
# rock05ck01-027.png is copying to valid folder
# rock02-019.png is copying to valid folder
# rock02-029.png is copying to valid folder
# rock02-075.png is copying to valid folder
# rock06ck02-105.png is copying to valid folder
# rock05ck01-095.png is copying to train folder
# rock06ck02-001.png is copying to valid folder
# rock04-109.png is copying to valid folder
# rock06ck02-092.png is copying to valid folder
# rock02-098.png is copying to train folder
# rock02-001.png is copying to train folder
# rock07-k03-050.png is copying to train folder
# rock04-065.png is copying to valid folder
# rock06ck02-108.png is copying to valid folder
# rock03-111.png is copying to valid folder
# rock07-k03-045.png is copying to valid folder
# rock04-075.png is copying to valid folder
# rock03-020.png is copying to valid folder
# rock04-117.png is copying to valid folder
# rock06ck02-061.png is copying to valid folder
# rock07-k03-003.png is copying to valid folder
# rock02-082.png is copying to valid folder
# rock05ck01-063.png is copying to valid folder
# rock06ck02-029.png is copying to valid folder
# rock07-k03-076.png is copying to valid folder
# ...
# scissors01-088.png is copying to train folder
# testscissors01-087.png is copying to train folder
# scissors03-049.png is copying to valid folder
# testscissors01-075.png is copying to train folder
# scissors01-048.png is copying to train folder
# scissors03-097.png is copying to valid folder
# testscissors03-073.png is copying to valid folder
# scissors03-015.png is copying to valid folder
# scissors03-000.png is copying to valid folder
# testscissors01-014.png is copying to valid folder
# testscissors03-022.png is copying to valid folder
# testscissors02-023.png is copying to valid folder
# testscissors01-117.png is copying to valid folder
# scissors01-002.png is copying to train folder
# scissors02-079.png is copying to valid folder
# testscissors01-068.png is copying to valid folder
# scissors01-057.png is copying to valid folder
# scissors02-095.png is copying to valid folder
# testscissors03-000.png is copying to valid folder
# testscissors02-007.png is copying to train folder
# testscissors01-009.png is copying to valid folder
# testscissors03-009.png is copying to valid folder
# scissors02-075.png is copying to valid folder
# testscissors03-083.png is copying to valid folder
# testscissors01-113.png is copying to valid folder
# scissors04-115.png is copying to valid folder
# testscissors03-029.png is copying to valid folder
# scissors03-095.png is copying to valid folder
# scissors02-055.png is copying to valid folder
# scissors01-064.png is copying to train folder
# scissors04-006.png is copying to valid folder
# testscissors03-015.png is copying to valid folder
# testscissors03-078.png is copying to valid folder
# testscissors03-053.png is copying to train folder
# testscissors02-060.png is copying to valid folder
# scissors02-104.png is copying to valid folder
# testscissors03-061.png is copying to valid folder
# testscissors01-048.png is copying to valid folder
# scissors01-026.png is copying to valid folder
# scissors04-091.png is copying to valid folder
# scissors03-031.png is copying to valid folder
# scissors02-070.png is copying to valid folder
# scissors03-093.png is copying to valid folder
# testscissors02-004.png is copying to valid folder
# scissors04-048.png is copying to valid folder
# testscissors03-092.png is copying to train folder
# testscissors01-102.png is copying to valid folder
# scissors01-103.png is copying to valid folder
# scissors04-113.png is copying to valid folder
# testscissors03-086.png is copying to valid folder
# testscissors02-079.png is copying to train folder
# testscissors03-071.png is copying to valid folder
# scissors03-004.png is copying to valid folder
# scissors02-012.png is copying to valid folder
# scissors01-063.png is copying to valid folder
# testscissors02-096.png is copying to train folder
# testscissors01-100.png is copying to valid folder
# testscissors01-098.png is copying to valid folder
# scissors01-047.png is copying to train folder
# scissors03-091.png is copying to valid folder
# scissors02-060.png is copying to valid folder
# testscissors03-020.png is copying to valid folder
# scissors03-006.png is copying to valid folder
# testscissors03-007.png is copying to train folder
# scissors02-031.png is copying to valid folder
# scissors03-002.png is copying to valid folder
# testscissors01-013.png is copying to valid folder
# testscissors03-046.png is copying to valid folder
# testscissors03-066.png is copying to valid folder
# scissors02-062.png is copying to valid folder
# testscissors01-016.png is copying to valid folder
# scissors01-117.png is copying to valid folder
# testscissors01-043.png is copying to valid folder
# scissors01-119.png is copying to valid folder
# scissors01-015.png is copying to valid folder
# scissors02-013.png is copying to valid folder
# testscissors03-067.png is copying to valid folder
# testscissors03-076.png is copying to valid folder
# scissors03-044.png is copying to valid folder
# testscissors02-011.png is copying to valid folder
# scissors01-034.png is copying to train folder
# scissors04-099.png is copying to train folder
# scissors04-064.png is copying to valid folder
# testscissors01-070.png is copying to train folder
# testscissors02-037.png is copying to train folder
# scissors02-088.png is copying to valid folder
# testscissors02-018.png is copying to valid folder
# scissors03-008.png is copying to valid folder
# scissors01-086.png is copying to valid folder
# testscissors02-015.png is copying to valid folder
# testscissors02-056.png is copying to valid folder
# scissors03-053.png is copying to valid folder
# scissors01-099.png is copying to train folder
# scissors01-046.png is copying to train folder
# testscissors01-062.png is copying to valid folder
# scissors04-059.png is copying to valid folder
# scissors02-036.png is copying to train folder
# testscissors01-106.png is copying to train folder
# testscissors01-003.png is copying to train folder
# scissors04-094.png is copying to train folder
# testscissors02-093.png is copying to valid folder
# scissors03-019.png is copying to valid folder
# testscissors02-022.png is copying to train folder
# testscissors01-104.png is copying to train folder
# testscissors01-018.png is copying to valid folder
# testscissors01-097.png is copying to valid folder
# testscissors03-069.png is copying to valid folder
# scissors04-110.png is copying to valid folder
# testscissors01-035.png is copying to valid folder
# scissors04-025.png is copying to train folder
# scissors02-044.png is copying to train folder
# scissors04-002.png is copying to valid folder
# scissors02-047.png is copying to valid folder
# scissors04-066.png is copying to valid folder
# testscissors01-092.png is copying to train folder
# scissors02-074.png is copying to train folder
# testscissors01-008.png is copying to valid folder
# scissors01-036.png is copying to valid folder
# scissors01-044.png is copying to train folder
# scissors03-062.png is copying to train folder
# testscissors01-027.png is copying to valid folder
# scissors02-068.png is copying to valid folder
# testscissors02-061.png is copying to valid folder
# scissors01-070.png is copying to valid folder
# scissors02-016.png is copying to valid folder
# testscissors02-064.png is copying to valid folder
# scissors04-087.png is copying to valid folder
# testscissors01-046.png is copying to train folder
# testscissors03-027.png is copying to valid folder
# testscissors03-063.png is copying to valid folder
# testscissors01-053.png is copying to valid folder
# testscissors01-012.png is copying to valid folder
# testscissors03-112.png is copying to valid folder
# scissors04-061.png is copying to valid folder
# testscissors03-059.png is copying to valid folder
# scissors04-097.png is copying to valid folder
# scissors03-094.png is copying to valid folder
# testscissors03-065.png is copying to valid folder
# testscissors02-085.png is copying to train folder
# scissors01-073.png is copying to valid folder
# scissors02-059.png is copying to valid folder
# scissors01-072.png is copying to train folder
# testscissors01-099.png is copying to valid folder
# testscissors03-087.png is copying to valid folder
# scissors01-111.png is copying to valid folder
# scissors03-078.png is copying to valid folder
# scissors02-114.png is copying to valid folder
# testscissors03-013.png is copying to valid folder
# scissors02-078.png is copying to valid folder
# testscissors01-080.png is copying to valid folder
# scissors04-103.png is copying to valid folder
# testscissors01-042.png is copying to valid folder
# scissors03-066.png is copying to valid folder
# testscissors02-046.png is copying to valid folder
# scissors02-028.png is copying to train folder
# scissors03-118.png is copying to valid folder
# scissors02-029.png is copying to valid folder
# testscissors02-074.png is copying to valid folder
# scissors03-070.png is copying to valid folder
# testscissors03-079.png is copying to train folder
# testscissors01-073.png is copying to valid folder
# scissors03-025.png is copying to valid folder
# testscissors01-011.png is copying to train folder
# scissors02-004.png is copying to valid folder
# testscissors03-055.png is copying to valid folder
# testscissors03-044.png is copying to valid folder
# testscissors01-031.png is copying to valid folder
# testscissors02-032.png is copying to valid folder
# testscissors02-075.png is copying to valid folder
# testscissors02-042.png is copying to valid folder
# scissors03-108.png is copying to valid folder
# testscissors03-060.png is copying to valid folder
# scissors04-090.png is copying to valid folder
# testscissors02-097.png is copying to valid folder
# scissors01-004.png is copying to valid folder
# scissors02-092.png is copying to valid folder
# testscissors02-069.png is copying to valid folder
# scissors01-106.png is copying to valid folder
# testscissors01-023.png is copying to valid folder
# scissors02-005.png is copying to valid folder
# scissors02-089.png is copying to valid folder
# testscissors03-024.png is copying to valid folder
# scissors04-086.png is copying to train folder
# scissors04-077.png is copying to valid folder
# scissors04-073.png is copying to valid folder
# scissors01-016.png is copying to valid folder
# testscissors03-037.png is copying to valid folder
# testscissors02-016.png is copying to train folder
# testscissors02-027.png is copying to valid folder
# testscissors02-029.png is copying to valid folder
# testscissors01-032.png is copying to valid folder
# testscissors02-006.png is copying to valid folder
# scissors03-077.png is copying to valid folder
# testscissors03-026.png is copying to valid folder
# testscissors03-006.png is copying to valid folder
# scissors01-018.png is copying to valid folder
# scissors02-054.png is copying to valid folder
# scissors01-005.png is copying to valid folder
# scissors03-092.png is copying to valid folder
# scissors03-029.png is copying to valid folder
# scissors04-045.png is copying to valid folder
# scissors04-013.png is copying to train folder
# testscissors03-028.png is copying to valid folder
# testscissors01-052.png is copying to train folder
# scissors02-042.png is copying to valid folder
# testscissors01-047.png is copying to valid folder
# scissors03-064.png is copying to valid folder
# testscissors02-052.png is copying to valid folder
# scissors03-084.png is copying to train folder
# scissors02-066.png is copying to valid folder
# scissors01-071.png is copying to valid folder
# scissors02-002.png is copying to valid folder
# scissors04-011.png is copying to valid folder
# scissors01-023.png is copying to valid folder
# testscissors02-103.png is copying to valid folder
# testscissors01-025.png is copying to valid folder
# testscissors01-021.png is copying to train folder
# scissors02-021.png is copying to valid folder
# scissors04-008.png is copying to valid folder
# scissors04-062.png is copying to valid folder
# scissors02-073.png is copying to valid folder
# scissors04-058.png is copying to train folder
# testscissors01-030.png is copying to valid folder
# scissors04-035.png is copying to valid folder
# scissors04-007.png is copying to valid folder
# testscissors02-071.png is copying to valid folder
# testscissors03-039.png is copying to valid folder
# testscissors01-063.png is copying to valid folder
# testscissors02-116.png is copying to train folder
# testscissors01-066.png is copying to valid folder
# scissors01-037.png is copying to train folder
# scissors02-111.png is copying to valid folder
# scissors04-032.png is copying to valid folder
# scissors01-007.png is copying to valid folder
# testscissors01-069.png is copying to train folder
# scissors04-075.png is copying to train folder
# scissors01-027.png is copying to valid folder
# scissors03-057.png is copying to valid folder
# testscissors02-033.png is copying to valid folder
# testscissors01-077.png is copying to train folder
# scissors02-052.png is copying to train folder
# scissors01-058.png is copying to valid folder
# scissors03-075.png is copying to valid folder
# testscissors03-047.png is copying to valid folder
# scissors01-060.png is copying to valid folder
# testscissors02-073.png is copying to train folder
# scissors01-089.png is copying to valid folder
# testscissors02-028.png is copying to train folder
# testscissors01-020.png is copying to valid folder
# testscissors03-050.png is copying to valid folder
# scissors02-096.png is copying to valid folder
# scissors04-019.png is copying to valid folder
# testscissors03-049.png is copying to valid folder
# scissors04-029.png is copying to valid folder
# testscissors01-001.png is copying to valid folder
# testscissors01-057.png is copying to valid folder
# testscissors03-080.png is copying to train folder
# testscissors03-102.png is copying to valid folder
# scissors01-042.png is copying to valid folder
# testscissors03-036.png is copying to valid folder
# scissors04-034.png is copying to valid folder
# scissors04-052.png is copying to valid folder
# scissors02-113.png is copying to valid folder
# scissors04-043.png is copying to valid folder
# scissors04-004.png is copying to valid folder
# scissors04-092.png is copying to valid folder
# scissors03-061.png is copying to valid folder
# scissors02-037.png is copying to train folder
# scissors01-098.png is copying to train folder
# scissors02-069.png is copying to valid folder
# scissors03-058.png is copying to valid folder
# testscissors03-034.png is copying to train folder
# scissors03-065.png is copying to valid folder
# scissors02-030.png is copying to valid folder
# scissors02-009.png is copying to valid folder
# scissors01-050.png is copying to valid folder
# scissors02-006.png is copying to valid folder
# testscissors01-089.png is copying to train folder
# testscissors01-006.png is copying to valid folder
# scissors03-052.png is copying to valid folder
# scissors04-065.png is copying to valid folder
# scissors03-003.png is copying to valid folder
# scissors02-050.png is copying to valid folder
# scissors02-023.png is copying to train folder
# scissors04-096.png is copying to valid folder
# testscissors02-089.png is copying to train folder
# scissors03-117.png is copying to train folder
# scissors04-039.png is copying to valid folder
# testscissors03-017.png is copying to valid folder
# scissors01-019.png is copying to valid folder
# testscissors01-072.png is copying to valid folder
# scissors04-047.png is copying to train folder
# scissors03-110.png is copying to valid folder
# testscissors01-074.png is copying to valid folder
# testscissors02-102.png is copying to valid folder
# scissors03-047.png is copying to valid folder
# testscissors02-068.png is copying to valid folder
# scissors03-033.png is copying to valid folder
# scissors04-069.png is copying to valid folder
# testscissors03-031.png is copying to valid folder
# testscissors02-092.png is copying to valid folder
# testscissors03-010.png is copying to valid folder
# scissors02-019.png is copying to valid folder
# testscissors03-096.png is copying to valid folder
# testscissors02-005.png is copying to valid folder
# scissors04-079.png is copying to valid folder
# testscissors03-042.png is copying to valid folder
# scissors01-065.png is copying to train folder
# scissors02-046.png is copying to train folder
# testscissors01-107.png is copying to valid folder
# testscissors01-093.png is copying to valid folder
# scissors01-100.png is copying to valid folder
# testscissors01-094.png is copying to valid folder
# testscissors01-050.png is copying to valid folder
# scissors03-024.png is copying to valid folder
# scissors02-022.png is copying to valid folder
# scissors02-063.png is copying to valid folder
# testscissors01-051.png is copying to valid folder
# testscissors02-013.png is copying to valid folder
# scissors01-033.png is copying to valid folder
# scissors02-072.png is copying to train folder
# testscissors03-070.png is copying to valid folder
# testscissors02-104.png is copying to valid folder
# scissors01-082.png is copying to valid folder
# scissors02-107.png is copying to valid folder
# scissors04-068.png is copying to train folder
# scissors04-081.png is copying to valid folder
# scissors02-105.png is copying to valid folder
# testscissors02-119.png is copying to valid folder
# scissors02-103.png is copying to train folder
# testscissors01-071.png is copying to valid folder
# testscissors02-017.png is copying to valid folder
# scissors01-084.png is copying to train folder
# scissors03-082.png is copying to train folder

# %%
# 다시풀기 
import urllib.request
import zipfile
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from keras_preprocessing.image import ImageDataGenerator

def solution_model():
    # url = 'https://storage.googleapis.com/download.tensorflow.org/data/rps.zip'
    # urllib.request.urlretrieve(url, 'rps.zip')
    # local_zip = 'rps.zip'
    # zip_ref = zipfile.ZipFile(local_zip, 'r')
    # zip_ref.extractall('./tmp/')
    # zip_ref.close()

    TRAINING_DIR = "./tmp/rps_train0/"
    VALID_DIR = "./tmp/rps_valid0/"
    training_datagen = ImageDataGenerator(
    # YOUR CODE HERE)
      rescale = 1/255., 
      zoom_range = 0.2, 
      width_shift_range = 0.1, 
      height_shift_range = 0.1 
    )

    train_generator =training_datagen.flow_from_directory(
        TRAINING_DIR, 
        target_size=(150,150),
        batch_size=32,
        class_mode = 'categorical'
    )

    valid_datagen = ImageDataGenerator(
        rescale = 1/255.
    )

    valid_generator = valid_datagen.flow_from_directory(
        VALID_DIR, 
        target_size=(150,150),
        batch_size=32,
        class_mode = 'categorical'
    )

    model = tf.keras.models.Sequential([
          Conv2D(32, (3,3), input_shape=(150,150,3), activation='relu'),                             
          MaxPool2D(2,2),
          Conv2D(64, (3,3), activation='relu'),
          MaxPool2D(2,2),
          Conv2D(128, (3,3), activation='relu'),
          MaxPool2D(2,2),
          Flatten(),
          Dropout(0.5), 
          Dense(256, activation='relu'),
          Dense(128, activation='relu'),
    # YOUR CODE HERE, BUT END WITH A 3 Neuron Dense, activated by softmax
        tf.keras.layers.Dense(3, activation='softmax')
    ])

    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['acc'])
    checkpoint_path = 'rps_checkpoint1-1.ckpt'
    checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                              save_weights_only = True, 
                              save_best_only = True, 
                              monitor='val_loss',
                              verbose=1)
    model.fit(train_generator, validation_data=valid_generator, epochs=20, 
            callbacks=[checkpoint]) 
    model.load_weights(checkpoint_path)
    return model



# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("TF3-rps1-1.h5")
# Out:
# Found 2016 images belonging to 3 classes.
# Found 504 images belonging to 3 classes.
# Epoch 1/20
# 63/63 [==============================] - 25s 285ms/step - loss: 1.0711 - acc: 0.4317 - val_loss: 0.2990 - val_acc: 0.8948
#
# Epoch 00001: val_loss improved from inf to 0.29901, saving model to rps_checkpoint1-1.ckpt
# Epoch 2/20
# 63/63 [==============================] - 17s 276ms/step - loss: 0.2684 - acc: 0.9040 - val_loss: 0.0368 - val_acc: 0.9901
#
# Epoch 00002: val_loss improved from 0.29901 to 0.03676, saving model to rps_checkpoint1-1.ckpt
# Epoch 3/20
# 63/63 [==============================] - 17s 274ms/step - loss: 0.0965 - acc: 0.9655 - val_loss: 0.0270 - val_acc: 0.9881
#
# Epoch 00003: val_loss improved from 0.03676 to 0.02697, saving model to rps_checkpoint1-1.ckpt
# Epoch 4/20
# 63/63 [==============================] - 17s 275ms/step - loss: 0.0837 - acc: 0.9745 - val_loss: 0.0057 - val_acc: 1.0000
#
# Epoch 00004: val_loss improved from 0.02697 to 0.00573, saving model to rps_checkpoint1-1.ckpt
# Epoch 5/20
# 63/63 [==============================] - 17s 273ms/step - loss: 0.0621 - acc: 0.9737 - val_loss: 0.0099 - val_acc: 0.9960
#
# Epoch 00005: val_loss did not improve from 0.00573
# Epoch 6/20
# 63/63 [==============================] - 17s 273ms/step - loss: 0.0594 - acc: 0.9805 - val_loss: 0.0084 - val_acc: 0.9980
#
# Epoch 00006: val_loss did not improve from 0.00573
# Epoch 7/20
# 63/63 [==============================] - 17s 271ms/step - loss: 0.0419 - acc: 0.9840 - val_loss: 0.0054 - val_acc: 1.0000
#
# Epoch 00007: val_loss improved from 0.00573 to 0.00539, saving model to rps_checkpoint1-1.ckpt
# Epoch 8/20
# 63/63 [==============================] - 17s 269ms/step - loss: 0.0310 - acc: 0.9894 - val_loss: 0.0046 - val_acc: 0.9980
#
# Epoch 00008: val_loss improved from 0.00539 to 0.00463, saving model to rps_checkpoint1-1.ckpt
# Epoch 9/20
# 63/63 [==============================] - 17s 272ms/step - loss: 0.0282 - acc: 0.9898 - val_loss: 0.0195 - val_acc: 0.9901
#
# Epoch 00009: val_loss did not improve from 0.00463
# Epoch 10/20
# 63/63 [==============================] - 17s 268ms/step - loss: 0.0242 - acc: 0.9918 - val_loss: 0.0042 - val_acc: 0.9980
#
# Epoch 00010: val_loss improved from 0.00463 to 0.00418, saving model to rps_checkpoint1-1.ckpt
# Epoch 11/20
# 63/63 [==============================] - 17s 268ms/step - loss: 0.0290 - acc: 0.9885 - val_loss: 0.0014 - val_acc: 1.0000
#
# Epoch 00011: val_loss improved from 0.00418 to 0.00138, saving model to rps_checkpoint1-1.ckpt
# Epoch 12/20
# 63/63 [==============================] - 17s 270ms/step - loss: 0.0239 - acc: 0.9932 - val_loss: 0.0017 - val_acc: 1.0000
#
# Epoch 00012: val_loss did not improve from 0.00138
# Epoch 13/20
# 63/63 [==============================] - 17s 271ms/step - loss: 0.0432 - acc: 0.9856 - val_loss: 0.0101 - val_acc: 0.9940
#
# Epoch 00013: val_loss did not improve from 0.00138
# Epoch 14/20
# 63/63 [==============================] - 17s 269ms/step - loss: 0.0244 - acc: 0.9920 - val_loss: 7.2966e-04 - val_acc: 1.0000
#
# Epoch 00014: val_loss improved from 0.00138 to 0.00073, saving model to rps_checkpoint1-1.ckpt
# Epoch 15/20
# 63/63 [==============================] - 17s 268ms/step - loss: 0.0106 - acc: 0.9975 - val_loss: 8.2236e-04 - val_acc: 1.0000
#
# Epoch 00015: val_loss did not improve from 0.00073
# Epoch 16/20
# 63/63 [==============================] - 17s 266ms/step - loss: 0.0080 - acc: 0.9982 - val_loss: 0.0188 - val_acc: 0.9921
#
# Epoch 00016: val_loss did not improve from 0.00073
# Epoch 17/20
# 63/63 [==============================] - 17s 263ms/step - loss: 0.0118 - acc: 0.9973 - val_loss: 6.6578e-05 - val_acc: 1.0000
#
# Epoch 00017: val_loss improved from 0.00073 to 0.00007, saving model to rps_checkpoint1-1.ckpt
# Epoch 18/20
# 63/63 [==============================] - 17s 262ms/step - loss: 0.0267 - acc: 0.9920 - val_loss: 0.0013 - val_acc: 1.0000
#
# Epoch 00018: val_loss did not improve from 0.00007
# Epoch 19/20
# 63/63 [==============================] - 17s 265ms/step - loss: 0.0075 - acc: 0.9992 - val_loss: 7.1139e-05 - val_acc: 1.0000
#
# Epoch 00019: val_loss did not improve from 0.00007
# Epoch 20/20
# 63/63 [==============================] - 16s 262ms/step - loss: 0.0093 - acc: 0.9973 - val_loss: 2.5195e-04 - val_acc: 1.0000
#
# Epoch 00020: val_loss did not improve from 0.00007
