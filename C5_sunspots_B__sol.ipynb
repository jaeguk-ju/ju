# %% [markdown]
# <a href="https://colab.research.google.com/github/jaeguk-ju/ju/blob/master/C5_sunspots_B__sol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
# For this task you will need to train a neural network
# to predict sunspot activity using the Sunspots.csv dataset.
# Your neural network must  have an MAE
# of 0.12 or less on the normalized dataset for top marks.
# Code for normalizing the data is provided and should not be changed.
# At the bottom of this file, we provide  some testing
# code should you want to check your model.

# Note: Do not use lambda layers in your model, they are not supported
# on the grading infrastructure.
# <번역> 
# 이 작업을 위해서는 신경망을 훈련시켜야합니다.
# Sunspots.csv 데이터 세트를 사용하여 흑점 활동을 예측합니다.
# 상위 마크에 대한 정규화 된 데이터 세트에서 0.12 이하의 MAE가 있어야합니다.
# 데이터 정규화를위한 코드가 제공되며 변경해서는 안됩니다.
# 당신의 모델을 체크하려면, 이 파일의 맨 아래에 몇 가지 테스팅 코드가 있습니다.
# 참고 : 모델에서 람다 레이어를 사용하지 마십시오. 채점 인프라에서 지원되지 않습니다.
 


import csv
import tensorflow as tf
import numpy as np
import urllib
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, LSTM 
from tensorflow.keras.optimizers import SGD, RMSprop
from tensorflow.keras.losses import Huber
from tensorflow.keras.callbacks import ModelCheckpoint


# DO NOT CHANGE THIS CODE
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)


def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/Sunspots.csv'
    urllib.request.urlretrieve(url, 'sunspots.csv')

    time_step = []
    sunspots = []

    with open('sunspots.csv') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        next(reader)
        for row in reader:
            sunspots.append(float(row[2]))   # YOUR CODE HERE
            time_step.append(int(row[0]))  # YOUR CODE HERE

    series =  np.array(sunspots)# YOUR CODE HERE

    # DO NOT CHANGE THIS CODE
    # This is the normalization function
    min = np.min(series)
    max = np.max(series)
    series -= min
    series /= max
    time = np.array(time_step)

    # The data should be split into training and validation sets at time step 3000
    # DO NOT CHANGE THIS CODE
    split_time = 3000


    time_train = time[:split_time]# YOUR CODE HERE
    x_train = series[:split_time]# YOUR CODE HERE
    time_valid = time[split_time:]# YOUR CODE HERE
    x_valid = series[split_time:] # YOUR CODE HERE

    # DO NOT CHANGE THIS CODE
    window_size = 30
    batch_size = 32
    shuffle_buffer_size = 1000

    train_set = windowed_dataset(x_train, window_size=window_size, batch_size=batch_size, shuffle_buffer=shuffle_buffer_size)
    valid_set = windowed_dataset(x_valid, window_size=window_size, batch_size=batch_size, shuffle_buffer=shuffle_buffer_size)

    model = tf.keras.models.Sequential([
        Conv1D(60, kernel_size=5, padding='causal', activation='relu', input_shape=[None,1]),
        LSTM(60,return_sequences=True),
        LSTM(60, return_sequences=True),
        Dense(30, activation='relu'),
        Dense(10, activation='relu'),                                  
        # YOUR CODE HERE. Whatever your first layer is, the input shape will be [None,1] when using the Windowed_dataset above, depending on the layer type chosen
        tf.keras.layers.Dense(1)
    ])
    opt = SGD(lr=1e-5, momentum=0.9)
    model.compile(loss=Huber(), optimizer=opt, metrics=['mae'])
    
    checkpoint_path = 'sunset_checkpoint1.ckpt'
    checkpoint = ModelCheckpoint(filepath = checkpoint_path, save_weights_only=True, save_best_only=True, 
                                monitor='val_mae', verbose=1)
    model.fit(train_set, validation_data = (valid_set), epochs=100, callbacks=[checkpoint])
    model.load_weights(checkpoint_path)
    # YOUR CODE HERE TO COMPILE AND TRAIN THE MODEL
    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, this .h5 model will be
# sent to the testing infrastructure for scoring.

# You must use the Submit and Test button to submit your model
# at least once in each category before you finally submit your exam.

if __name__ == '__main__':
    model = solution_model()
    model.save("cat5_sunspots(typeB).h5")



# THIS CODE IS USED IN THE TESTER FOR FORECASTING. IF YOU WANT TO TEST YOUR MODEL
# BEFORE UPLOADING YOU CAN DO IT WITH THIS
#def model_forecast(model, series, window_size):
#    ds = tf.data.Dataset.from_tensor_slices(series)
#    ds = ds.window(window_size, shift=1, drop_remainder=True)
#    ds = ds.flat_map(lambda w: w.batch(window_size))
#    ds = ds.batch(32).prefetch(1)
#    forecast = model.predict(ds)
#    return forecast


#window_size = # YOUR CODE HERE
#rnn_forecast = model_forecast(model, series[..., np.newaxis], window_size)
#rnn_forecast = rnn_forecast[split_time - window_size:-1, -1, 0]

#result = tf.keras.metrics.mean_absolute_error(x_valid, rnn_forecast).numpy()

## To get the maximum score, your model must have an MAE OF .12 or less.
## When you Submit and Test your model, the grading infrastructure
## converts the MAE of your model to a score from 0 to 5 as follows:

#test_val = 100 * result
#score = math.ceil(17 - test_val)
#if score > 5:
#    score = 5

#print(score)
# Out:
# Epoch 1/100
# 93/93 [==============================] - 10s 20ms/step - loss: 0.0345 - mae: 0.2013 - val_loss: 0.0259 - val_mae: 0.1787
#
# Epoch 00001: val_mae improved from inf to 0.17865, saving model to sunset_checkpoint1.ckpt
# Epoch 2/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0322 - mae: 0.1923 - val_loss: 0.0255 - val_mae: 0.1764
#
# Epoch 00002: val_mae improved from 0.17865 to 0.17644, saving model to sunset_checkpoint1.ckpt
# Epoch 3/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0329 - mae: 0.1952 - val_loss: 0.0251 - val_mae: 0.1745
#
# Epoch 00003: val_mae improved from 0.17644 to 0.17455, saving model to sunset_checkpoint1.ckpt
# Epoch 4/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0315 - mae: 0.1903 - val_loss: 0.0248 - val_mae: 0.1728
#
# Epoch 00004: val_mae improved from 0.17455 to 0.17278, saving model to sunset_checkpoint1.ckpt
# Epoch 5/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0314 - mae: 0.1884 - val_loss: 0.0245 - val_mae: 0.1711
#
# Epoch 00005: val_mae improved from 0.17278 to 0.17110, saving model to sunset_checkpoint1.ckpt
# Epoch 6/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0327 - mae: 0.1939 - val_loss: 0.0241 - val_mae: 0.1695
#
# Epoch 00006: val_mae improved from 0.17110 to 0.16948, saving model to sunset_checkpoint1.ckpt
# Epoch 7/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0311 - mae: 0.1868 - val_loss: 0.0238 - val_mae: 0.1679
#
# Epoch 00007: val_mae improved from 0.16948 to 0.16791, saving model to sunset_checkpoint1.ckpt
# Epoch 8/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0321 - mae: 0.1896 - val_loss: 0.0235 - val_mae: 0.1664
#
# Epoch 00008: val_mae improved from 0.16791 to 0.16638, saving model to sunset_checkpoint1.ckpt
# Epoch 9/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0308 - mae: 0.1858 - val_loss: 0.0232 - val_mae: 0.1649
#
# Epoch 00009: val_mae improved from 0.16638 to 0.16487, saving model to sunset_checkpoint1.ckpt
# Epoch 10/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0299 - mae: 0.1812 - val_loss: 0.0229 - val_mae: 0.1634
#
# Epoch 00010: val_mae improved from 0.16487 to 0.16338, saving model to sunset_checkpoint1.ckpt
# Epoch 11/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0299 - mae: 0.1815 - val_loss: 0.0225 - val_mae: 0.1618
#
# Epoch 00011: val_mae improved from 0.16338 to 0.16183, saving model to sunset_checkpoint1.ckpt
# Epoch 12/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0300 - mae: 0.1823 - val_loss: 0.0222 - val_mae: 0.1602
#
# Epoch 00012: val_mae improved from 0.16183 to 0.16021, saving model to sunset_checkpoint1.ckpt
# Epoch 13/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0300 - mae: 0.1812 - val_loss: 0.0218 - val_mae: 0.1586
#
# Epoch 00013: val_mae improved from 0.16021 to 0.15856, saving model to sunset_checkpoint1.ckpt
# Epoch 14/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0290 - mae: 0.1763 - val_loss: 0.0215 - val_mae: 0.1569
#
# Epoch 00014: val_mae improved from 0.15856 to 0.15690, saving model to sunset_checkpoint1.ckpt
# Epoch 15/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0286 - mae: 0.1749 - val_loss: 0.0211 - val_mae: 0.1552
#
# Epoch 00015: val_mae improved from 0.15690 to 0.15524, saving model to sunset_checkpoint1.ckpt
# Epoch 16/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0275 - mae: 0.1724 - val_loss: 0.0207 - val_mae: 0.1536
#
# Epoch 00016: val_mae improved from 0.15524 to 0.15358, saving model to sunset_checkpoint1.ckpt
# Epoch 17/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0281 - mae: 0.1745 - val_loss: 0.0204 - val_mae: 0.1520
#
# Epoch 00017: val_mae improved from 0.15358 to 0.15198, saving model to sunset_checkpoint1.ckpt
# Epoch 18/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0270 - mae: 0.1684 - val_loss: 0.0201 - val_mae: 0.1504
#
# Epoch 00018: val_mae improved from 0.15198 to 0.15045, saving model to sunset_checkpoint1.ckpt
# Epoch 19/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0268 - mae: 0.1689 - val_loss: 0.0197 - val_mae: 0.1489
#
# Epoch 00019: val_mae improved from 0.15045 to 0.14895, saving model to sunset_checkpoint1.ckpt
# Epoch 20/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0274 - mae: 0.1709 - val_loss: 0.0194 - val_mae: 0.1475
#
# Epoch 00020: val_mae improved from 0.14895 to 0.14749, saving model to sunset_checkpoint1.ckpt
# Epoch 21/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0253 - mae: 0.1620 - val_loss: 0.0191 - val_mae: 0.1461
#
# Epoch 00021: val_mae improved from 0.14749 to 0.14610, saving model to sunset_checkpoint1.ckpt
# Epoch 22/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0259 - mae: 0.1650 - val_loss: 0.0188 - val_mae: 0.1448
#
# Epoch 00022: val_mae improved from 0.14610 to 0.14476, saving model to sunset_checkpoint1.ckpt
# Epoch 23/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0254 - mae: 0.1621 - val_loss: 0.0185 - val_mae: 0.1435
#
# Epoch 00023: val_mae improved from 0.14476 to 0.14350, saving model to sunset_checkpoint1.ckpt
# Epoch 24/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0243 - mae: 0.1587 - val_loss: 0.0183 - val_mae: 0.1423
#
# Epoch 00024: val_mae improved from 0.14350 to 0.14230, saving model to sunset_checkpoint1.ckpt
# Epoch 25/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0238 - mae: 0.1571 - val_loss: 0.0180 - val_mae: 0.1412
#
# Epoch 00025: val_mae improved from 0.14230 to 0.14116, saving model to sunset_checkpoint1.ckpt
# Epoch 26/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0250 - mae: 0.1608 - val_loss: 0.0177 - val_mae: 0.1401
#
# Epoch 00026: val_mae improved from 0.14116 to 0.14008, saving model to sunset_checkpoint1.ckpt
# Epoch 27/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0251 - mae: 0.1613 - val_loss: 0.0175 - val_mae: 0.1391
#
# Epoch 00027: val_mae improved from 0.14008 to 0.13906, saving model to sunset_checkpoint1.ckpt
# Epoch 28/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0242 - mae: 0.1571 - val_loss: 0.0172 - val_mae: 0.1381
#
# Epoch 00028: val_mae improved from 0.13906 to 0.13807, saving model to sunset_checkpoint1.ckpt
# Epoch 29/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0240 - mae: 0.1575 - val_loss: 0.0170 - val_mae: 0.1371
#
# Epoch 00029: val_mae improved from 0.13807 to 0.13710, saving model to sunset_checkpoint1.ckpt
# Epoch 30/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0242 - mae: 0.1584 - val_loss: 0.0167 - val_mae: 0.1362
#
# Epoch 00030: val_mae improved from 0.13710 to 0.13618, saving model to sunset_checkpoint1.ckpt
# Epoch 31/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0234 - mae: 0.1549 - val_loss: 0.0165 - val_mae: 0.1353
#
# Epoch 00031: val_mae improved from 0.13618 to 0.13531, saving model to sunset_checkpoint1.ckpt
# Epoch 32/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0228 - mae: 0.1530 - val_loss: 0.0163 - val_mae: 0.1345
#
# Epoch 00032: val_mae improved from 0.13531 to 0.13448, saving model to sunset_checkpoint1.ckpt
# Epoch 33/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0223 - mae: 0.1515 - val_loss: 0.0161 - val_mae: 0.1337
#
# Epoch 00033: val_mae improved from 0.13448 to 0.13367, saving model to sunset_checkpoint1.ckpt
# Epoch 34/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0218 - mae: 0.1492 - val_loss: 0.0159 - val_mae: 0.1329
#
# Epoch 00034: val_mae improved from 0.13367 to 0.13290, saving model to sunset_checkpoint1.ckpt
# Epoch 35/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0216 - mae: 0.1487 - val_loss: 0.0157 - val_mae: 0.1321
#
# Epoch 00035: val_mae improved from 0.13290 to 0.13215, saving model to sunset_checkpoint1.ckpt
# Epoch 36/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0217 - mae: 0.1488 - val_loss: 0.0155 - val_mae: 0.1314
#
# Epoch 00036: val_mae improved from 0.13215 to 0.13142, saving model to sunset_checkpoint1.ckpt
# Epoch 37/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0214 - mae: 0.1479 - val_loss: 0.0153 - val_mae: 0.1307
#
# Epoch 00037: val_mae improved from 0.13142 to 0.13073, saving model to sunset_checkpoint1.ckpt
# Epoch 38/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0221 - mae: 0.1510 - val_loss: 0.0151 - val_mae: 0.1301
#
# Epoch 00038: val_mae improved from 0.13073 to 0.13007, saving model to sunset_checkpoint1.ckpt
# Epoch 39/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0208 - mae: 0.1468 - val_loss: 0.0149 - val_mae: 0.1294
#
# Epoch 00039: val_mae improved from 0.13007 to 0.12944, saving model to sunset_checkpoint1.ckpt
# Epoch 40/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0207 - mae: 0.1455 - val_loss: 0.0148 - val_mae: 0.1288
#
# Epoch 00040: val_mae improved from 0.12944 to 0.12880, saving model to sunset_checkpoint1.ckpt
# Epoch 41/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0205 - mae: 0.1452 - val_loss: 0.0146 - val_mae: 0.1282
#
# Epoch 00041: val_mae improved from 0.12880 to 0.12819, saving model to sunset_checkpoint1.ckpt
# Epoch 42/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0210 - mae: 0.1465 - val_loss: 0.0144 - val_mae: 0.1276
#
# Epoch 00042: val_mae improved from 0.12819 to 0.12761, saving model to sunset_checkpoint1.ckpt
# Epoch 43/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0198 - mae: 0.1423 - val_loss: 0.0143 - val_mae: 0.1270
#
# Epoch 00043: val_mae improved from 0.12761 to 0.12704, saving model to sunset_checkpoint1.ckpt
# Epoch 44/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0209 - mae: 0.1470 - val_loss: 0.0141 - val_mae: 0.1265
#
# Epoch 00044: val_mae improved from 0.12704 to 0.12650, saving model to sunset_checkpoint1.ckpt
# Epoch 45/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0203 - mae: 0.1439 - val_loss: 0.0140 - val_mae: 0.1260
#
# Epoch 00045: val_mae improved from 0.12650 to 0.12596, saving model to sunset_checkpoint1.ckpt
# Epoch 46/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0196 - mae: 0.1422 - val_loss: 0.0138 - val_mae: 0.1254
#
# Epoch 00046: val_mae improved from 0.12596 to 0.12545, saving model to sunset_checkpoint1.ckpt
# Epoch 47/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0191 - mae: 0.1401 - val_loss: 0.0137 - val_mae: 0.1249
#
# Epoch 00047: val_mae improved from 0.12545 to 0.12495, saving model to sunset_checkpoint1.ckpt
# Epoch 48/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0194 - mae: 0.1415 - val_loss: 0.0136 - val_mae: 0.1245
#
# Epoch 00048: val_mae improved from 0.12495 to 0.12446, saving model to sunset_checkpoint1.ckpt
# Epoch 49/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0197 - mae: 0.1421 - val_loss: 0.0134 - val_mae: 0.1240
#
# Epoch 00049: val_mae improved from 0.12446 to 0.12402, saving model to sunset_checkpoint1.ckpt
# Epoch 50/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0190 - mae: 0.1397 - val_loss: 0.0133 - val_mae: 0.1236
#
# Epoch 00050: val_mae improved from 0.12402 to 0.12359, saving model to sunset_checkpoint1.ckpt
# Epoch 51/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0199 - mae: 0.1434 - val_loss: 0.0132 - val_mae: 0.1232
#
# Epoch 00051: val_mae improved from 0.12359 to 0.12317, saving model to sunset_checkpoint1.ckpt
# Epoch 52/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0187 - mae: 0.1394 - val_loss: 0.0131 - val_mae: 0.1228
#
# Epoch 00052: val_mae improved from 0.12317 to 0.12278, saving model to sunset_checkpoint1.ckpt
# Epoch 53/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0189 - mae: 0.1396 - val_loss: 0.0129 - val_mae: 0.1224
#
# Epoch 00053: val_mae improved from 0.12278 to 0.12239, saving model to sunset_checkpoint1.ckpt
# Epoch 54/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0180 - mae: 0.1364 - val_loss: 0.0128 - val_mae: 0.1220
#
# Epoch 00054: val_mae improved from 0.12239 to 0.12201, saving model to sunset_checkpoint1.ckpt
# Epoch 55/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0182 - mae: 0.1372 - val_loss: 0.0127 - val_mae: 0.1216
#
# Epoch 00055: val_mae improved from 0.12201 to 0.12164, saving model to sunset_checkpoint1.ckpt
# Epoch 56/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0180 - mae: 0.1366 - val_loss: 0.0126 - val_mae: 0.1213
#
# Epoch 00056: val_mae improved from 0.12164 to 0.12127, saving model to sunset_checkpoint1.ckpt
# Epoch 57/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0185 - mae: 0.1388 - val_loss: 0.0125 - val_mae: 0.1209
#
# Epoch 00057: val_mae improved from 0.12127 to 0.12091, saving model to sunset_checkpoint1.ckpt
# Epoch 58/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0175 - mae: 0.1341 - val_loss: 0.0124 - val_mae: 0.1206
#
# Epoch 00058: val_mae improved from 0.12091 to 0.12055, saving model to sunset_checkpoint1.ckpt
# Epoch 59/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0173 - mae: 0.1347 - val_loss: 0.0123 - val_mae: 0.1202
#
# Epoch 00059: val_mae improved from 0.12055 to 0.12021, saving model to sunset_checkpoint1.ckpt
# Epoch 60/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0173 - mae: 0.1341 - val_loss: 0.0122 - val_mae: 0.1199
#
# Epoch 00060: val_mae improved from 0.12021 to 0.11987, saving model to sunset_checkpoint1.ckpt
# Epoch 61/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0172 - mae: 0.1342 - val_loss: 0.0121 - val_mae: 0.1195
#
# Epoch 00061: val_mae improved from 0.11987 to 0.11953, saving model to sunset_checkpoint1.ckpt
# Epoch 62/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0177 - mae: 0.1361 - val_loss: 0.0120 - val_mae: 0.1192
#
# Epoch 00062: val_mae improved from 0.11953 to 0.11921, saving model to sunset_checkpoint1.ckpt
# Epoch 63/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0175 - mae: 0.1349 - val_loss: 0.0120 - val_mae: 0.1189
#
# Epoch 00063: val_mae improved from 0.11921 to 0.11890, saving model to sunset_checkpoint1.ckpt
# Epoch 64/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0171 - mae: 0.1337 - val_loss: 0.0119 - val_mae: 0.1186
#
# Epoch 00064: val_mae improved from 0.11890 to 0.11858, saving model to sunset_checkpoint1.ckpt
# Epoch 65/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0161 - mae: 0.1300 - val_loss: 0.0118 - val_mae: 0.1183
#
# Epoch 00065: val_mae improved from 0.11858 to 0.11828, saving model to sunset_checkpoint1.ckpt
# Epoch 66/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0173 - mae: 0.1346 - val_loss: 0.0117 - val_mae: 0.1180
#
# Epoch 00066: val_mae improved from 0.11828 to 0.11798, saving model to sunset_checkpoint1.ckpt
# Epoch 67/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0170 - mae: 0.1335 - val_loss: 0.0116 - val_mae: 0.1177
#
# Epoch 00067: val_mae improved from 0.11798 to 0.11769, saving model to sunset_checkpoint1.ckpt
# Epoch 68/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0166 - mae: 0.1325 - val_loss: 0.0116 - val_mae: 0.1174
#
# Epoch 00068: val_mae improved from 0.11769 to 0.11740, saving model to sunset_checkpoint1.ckpt
# Epoch 69/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0167 - mae: 0.1327 - val_loss: 0.0115 - val_mae: 0.1171
#
# Epoch 00069: val_mae improved from 0.11740 to 0.11713, saving model to sunset_checkpoint1.ckpt
# Epoch 70/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0167 - mae: 0.1329 - val_loss: 0.0114 - val_mae: 0.1169
#
# Epoch 00070: val_mae improved from 0.11713 to 0.11687, saving model to sunset_checkpoint1.ckpt
# Epoch 71/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0166 - mae: 0.1323 - val_loss: 0.0113 - val_mae: 0.1166
#
# Epoch 00071: val_mae improved from 0.11687 to 0.11660, saving model to sunset_checkpoint1.ckpt
# Epoch 72/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0161 - mae: 0.1310 - val_loss: 0.0113 - val_mae: 0.1164
#
# Epoch 00072: val_mae improved from 0.11660 to 0.11635, saving model to sunset_checkpoint1.ckpt
# Epoch 73/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0158 - mae: 0.1297 - val_loss: 0.0112 - val_mae: 0.1161
#
# Epoch 00073: val_mae improved from 0.11635 to 0.11611, saving model to sunset_checkpoint1.ckpt
# Epoch 74/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0157 - mae: 0.1293 - val_loss: 0.0112 - val_mae: 0.1159
#
# Epoch 00074: val_mae improved from 0.11611 to 0.11587, saving model to sunset_checkpoint1.ckpt
# Epoch 75/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0166 - mae: 0.1332 - val_loss: 0.0111 - val_mae: 0.1156
#
# Epoch 00075: val_mae improved from 0.11587 to 0.11564, saving model to sunset_checkpoint1.ckpt
# Epoch 76/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0160 - mae: 0.1306 - val_loss: 0.0110 - val_mae: 0.1154
#
# Epoch 00076: val_mae improved from 0.11564 to 0.11543, saving model to sunset_checkpoint1.ckpt
# Epoch 77/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0162 - mae: 0.1322 - val_loss: 0.0110 - val_mae: 0.1152
#
# Epoch 00077: val_mae improved from 0.11543 to 0.11522, saving model to sunset_checkpoint1.ckpt
# Epoch 78/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0162 - mae: 0.1319 - val_loss: 0.0109 - val_mae: 0.1150
#
# Epoch 00078: val_mae improved from 0.11522 to 0.11502, saving model to sunset_checkpoint1.ckpt
# Epoch 79/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0158 - mae: 0.1304 - val_loss: 0.0109 - val_mae: 0.1148
#
# Epoch 00079: val_mae improved from 0.11502 to 0.11483, saving model to sunset_checkpoint1.ckpt
# Epoch 80/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0161 - mae: 0.1319 - val_loss: 0.0108 - val_mae: 0.1146
#
# Epoch 00080: val_mae improved from 0.11483 to 0.11463, saving model to sunset_checkpoint1.ckpt
# Epoch 81/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0155 - mae: 0.1291 - val_loss: 0.0108 - val_mae: 0.1145
#
# Epoch 00081: val_mae improved from 0.11463 to 0.11445, saving model to sunset_checkpoint1.ckpt
# Epoch 82/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0153 - mae: 0.1286 - val_loss: 0.0107 - val_mae: 0.1143
#
# Epoch 00082: val_mae improved from 0.11445 to 0.11428, saving model to sunset_checkpoint1.ckpt
# Epoch 83/100
# 93/93 [==============================] - 1s 11ms/step - loss: 0.0155 - mae: 0.1291 - val_loss: 0.0107 - val_mae: 0.1141
#
# Epoch 00083: val_mae improved from 0.11428 to 0.11412, saving model to sunset_checkpoint1.ckpt
# Epoch 84/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0156 - mae: 0.1299 - val_loss: 0.0106 - val_mae: 0.1140
#
# Epoch 00084: val_mae improved from 0.11412 to 0.11396, saving model to sunset_checkpoint1.ckpt
# Epoch 85/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0154 - mae: 0.1294 - val_loss: 0.0106 - val_mae: 0.1138
#
# Epoch 00085: val_mae improved from 0.11396 to 0.11381, saving model to sunset_checkpoint1.ckpt
# Epoch 86/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0157 - mae: 0.1310 - val_loss: 0.0105 - val_mae: 0.1137
#
# Epoch 00086: val_mae improved from 0.11381 to 0.11367, saving model to sunset_checkpoint1.ckpt
# Epoch 87/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0155 - mae: 0.1302 - val_loss: 0.0105 - val_mae: 0.1135
#
# Epoch 00087: val_mae improved from 0.11367 to 0.11352, saving model to sunset_checkpoint1.ckpt
# Epoch 88/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0156 - mae: 0.1309 - val_loss: 0.0105 - val_mae: 0.1134
#
# Epoch 00088: val_mae improved from 0.11352 to 0.11339, saving model to sunset_checkpoint1.ckpt
# Epoch 89/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0155 - mae: 0.1303 - val_loss: 0.0104 - val_mae: 0.1133
#
# Epoch 00089: val_mae improved from 0.11339 to 0.11326, saving model to sunset_checkpoint1.ckpt
# Epoch 90/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0150 - mae: 0.1283 - val_loss: 0.0104 - val_mae: 0.1131
#
# Epoch 00090: val_mae improved from 0.11326 to 0.11314, saving model to sunset_checkpoint1.ckpt
# Epoch 91/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0155 - mae: 0.1305 - val_loss: 0.0104 - val_mae: 0.1130
#
# Epoch 00091: val_mae improved from 0.11314 to 0.11302, saving model to sunset_checkpoint1.ckpt
# Epoch 92/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0152 - mae: 0.1299 - val_loss: 0.0103 - val_mae: 0.1129
#
# Epoch 00092: val_mae improved from 0.11302 to 0.11291, saving model to sunset_checkpoint1.ckpt
# Epoch 93/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0153 - mae: 0.1300 - val_loss: 0.0103 - val_mae: 0.1128
#
# Epoch 00093: val_mae improved from 0.11291 to 0.11282, saving model to sunset_checkpoint1.ckpt
# Epoch 94/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0143 - mae: 0.1265 - val_loss: 0.0103 - val_mae: 0.1127
#
# Epoch 00094: val_mae improved from 0.11282 to 0.11272, saving model to sunset_checkpoint1.ckpt
# Epoch 95/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0150 - mae: 0.1287 - val_loss: 0.0102 - val_mae: 0.1126
#
# Epoch 00095: val_mae improved from 0.11272 to 0.11264, saving model to sunset_checkpoint1.ckpt
# Epoch 96/100
# 93/93 [==============================] - 1s 10ms/step - loss: 0.0148 - mae: 0.1285 - val_loss: 0.0102 - val_mae: 0.1126
#
# Epoch 00096: val_mae improved from 0.11264 to 0.11256, saving model to sunset_checkpoint1.ckpt
# Epoch 97/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0147 - mae: 0.1278 - val_loss: 0.0102 - val_mae: 0.1125
#
# Epoch 00097: val_mae improved from 0.11256 to 0.11248, saving model to sunset_checkpoint1.ckpt
# Epoch 98/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0149 - mae: 0.1291 - val_loss: 0.0101 - val_mae: 0.1124
#
# Epoch 00098: val_mae improved from 0.11248 to 0.11241, saving model to sunset_checkpoint1.ckpt
# Epoch 99/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0147 - mae: 0.1278 - val_loss: 0.0101 - val_mae: 0.1123
#
# Epoch 00099: val_mae improved from 0.11241 to 0.11234, saving model to sunset_checkpoint1.ckpt
# Epoch 100/100
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0151 - mae: 0.1301 - val_loss: 0.0101 - val_mae: 0.1123
#
# Epoch 00100: val_mae improved from 0.11234 to 0.11228, saving model to sunset_checkpoint1.ckpt
